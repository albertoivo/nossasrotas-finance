# %% [markdown]
# # ALPHA VANTAGE BITCOIN

# %%
from alpha_vantage.cryptocurrencies import CryptoCurrencies
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
cc = CryptoCurrencies(key='1VI1L6694V2Q3CFA', output_format='pandas')
data, meta_data = cc.get_digital_currency_daily(symbol='BTC', market='BRL')

# %%
data.drop(labels='6. market cap (USD)', axis=1, inplace=True)

# %%
data.head()
# Out:
#             1a. open (BRL)  1b. open (USD)  2a. high (BRL)  2b. high (USD)  \
# date
# 2019-12-04    30666.574821         7292.71    30672.125553         7294.03
# 2019-12-03    30673.765542         7294.42    31117.740000         7400.00
# 2019-12-02    31081.996650         7391.50    31204.196856         7420.56
# 2019-12-01    31709.103213         7540.63    31714.233435         7541.85
# 2019-11-30    32551.637049         7740.99    32841.831000         7810.00
#
#             3a. low (BRL)  3b. low (USD)  4a. close (BRL)  4b. close (USD)  \
# date
# 2019-12-04   29864.620200        7102.00     30131.601999          7165.49
# 2019-12-03   30450.600885        7241.35     30666.574821          7292.71
# 2019-12-02   30071.090610        7151.10     30673.176828          7294.28
# 2019-12-01   30318.771000        7210.00     31079.431539          7390.89
# 2019-11-30   31290.149100        7441.00     31714.401639          7541.89
#
#                5. volume
# date
# 2019-12-04   8709.465392
# 2019-12-03  33149.477487
# 2019-12-02  46330.256040
# 2019-12-01  60769.342313
# 2019-11-30  46989.433619

# %%
data['4a. close (BRL)'].plot(figsize=(17,10))
plt.tight_layout()
plt.title('Daily value for bitcoin in BRL')
plt.grid()
plt.show()

# %%
data['4b. close (USD)'].plot(figsize=(17,10))
plt.tight_layout()
plt.title('Daily value for bitcoin in USD')
plt.grid()
plt.show()

# %%
from alpha_vantage.foreignexchange import ForeignExchange

cc = ForeignExchange(key='1VI1L6694V2Q3CFA')

# %%
btcusd, _ = cc.get_currency_exchange_rate(from_currency='BTC',to_currency='USD')
btcusd
# Out:
# {'1. From_Currency Code': 'BTC',
#  '2. From_Currency Name': 'Bitcoin',
#  '3. To_Currency Code': 'USD',
#  '4. To_Currency Name': 'United States Dollar',
#  '5. Exchange Rate': '7473.53000000',
#  '6. Last Refreshed': '2019-12-04 18:58:02',
#  '7. Time Zone': 'UTC',
#  '8. Bid Price': '7473.32000000',
#  '9. Ask Price': '7473.99000000'}

# %%
btcbrl, _ = cc.get_currency_exchange_rate(from_currency='BTC',to_currency='BRL')
btcbrl
# Out:
# {'1. From_Currency Code': 'BTC',
#  '2. From_Currency Name': 'Bitcoin',
#  '3. To_Currency Code': 'BRL',
#  '4. To_Currency Name': 'Brazilian Real',
#  '5. Exchange Rate': '31348.23600600',
#  '6. Last Refreshed': '2019-12-04 18:58:49',
#  '7. Time Zone': 'UTC',
#  '8. Bid Price': '31348.19405700',
#  '9. Ask Price': '31348.23600600'}

# %%
cadbrl, _ = cc.get_currency_exchange_rate(from_currency='CAD',to_currency='BRL')
cadbrl
# Out:
# {'1. From_Currency Code': 'CAD',
#  '2. From_Currency Name': 'Canadian Dollar',
#  '3. To_Currency Code': 'BRL',
#  '4. To_Currency Name': 'Brazilian Real',
#  '5. Exchange Rate': '3.18130000',
#  '6. Last Refreshed': '2019-12-04 18:58:13',
#  '7. Time Zone': 'UTC',
#  '8. Bid Price': '3.17850000',
#  '9. Ask Price': '3.18400000'}
