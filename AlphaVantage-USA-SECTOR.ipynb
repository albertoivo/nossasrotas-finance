# %% [markdown]
# # ALPHA VANTAGE USA SECTORS

# %%
from alpha_vantage.sectorperformance import SectorPerformances
import matplotlib.pyplot as plt

# %%
sp = SectorPerformances(key='1VI1L6694V2Q3CFA', output_format='pandas')

df, md = sp.get_sector()

# %%
df.columns = ['Real-Time', '1 Day', '5 Day', '1 Month', '3 Month',
             'YTD', '1 Year', '3 Year', '5 Year', '10 Year']

# %%
df.drop(labels='Real-Time', axis=1, inplace=True)

# %%
df['STD'] = df.std(axis=1)

# %%
df.sort_values(by='10 Year')
# Out:
#                          1 Day   5 Day  1 Month  3 Month     YTD  1 Year  \
# Energy                  0.0105  0.0042  -0.0896  -0.0795  0.0238 -0.2166
# Communication Services  0.0153  0.0149  -0.0231   0.0149  0.2018  0.0957
# Materials               0.0113  0.0203  -0.0166   0.0442  0.1369 -0.0217
# Utilities               0.0016  0.0114   0.0011   0.0489  0.1462  0.1473
# Financials              0.0123 -0.0058  -0.0495  -0.0183  0.1284 -0.0369
# Consumer Staples        0.0120  0.0234  -0.0057   0.0410  0.1733  0.1206
# Industrials             0.0114  0.0047  -0.0416  -0.0136  0.1675  0.0035
# Health Care             0.0131  0.0181  -0.0090   0.0320  0.0587  0.0228
# Information Technology  0.0247  0.0296  -0.0235   0.0426  0.2782  0.0857
# Consumer Discretionary  0.0171  0.0157  -0.0511   0.0057  0.1970  0.0431
# Real Estate             0.0018  0.0250   0.0214   0.0655  0.2372  0.1720
#
#                         3 Year  5 Year  10 Year       STD
# Energy                 -0.1456 -0.3778   0.1137  0.147971
# Communication Services -0.0718  0.0540   0.5882  0.199108
# Materials               0.1885  0.1573   0.9987  0.320803
# Utilities               0.1958  0.4729   1.0910  0.353599
# Financials              0.3898  0.4799   1.3657  0.460689
# Consumer Staples        0.0869  0.3487   1.4498  0.463080
# Industrials             0.2485  0.4058   1.9036  0.620117
# Health Care             0.2268  0.5163   2.2748  0.741052
# Information Technology  0.7787  1.1753   3.3975  1.112202
# Consumer Discretionary  0.4372  0.7755   3.5349  1.150094
# Real Estate                NaN     NaN      NaN  0.095555

# %%
df['1 Year'].plot(kind='bar', figsize=(10,4))
plt.title('1 Year')
plt.grid()

# %%
df['3 Year'].plot(kind='bar', figsize=(10,4))
plt.title('3 Year')
plt.grid()

# %%
df['5 Year'].plot(kind='bar', figsize=(10,4))
plt.title('5 Year')
plt.grid()

# %%
df['10 Year'].plot(kind='bar', figsize=(10,4))
plt.title('10 Year')
plt.grid()
