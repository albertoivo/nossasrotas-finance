# %% [markdown]
# # ALPHA VANTAGE USA SECTORS

# %% [markdown]
# ## Lendo JSON

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

API_URL = "https://www.alphavantage.co/query"

data = {
    "function": "SECTOR",
    "apikey": "1VI1L6694V2Q3CFA",
}

response = requests.get(API_URL, params=data)

info = response.json()

# %%
df = pd.DataFrame(info)
df.drop('Meta Data', axis=1, inplace=True)
df.drop('Information', inplace=True)
df.drop('Last Refreshed', inplace=True)

# %%
df.columns = ['Real-Time', '1 Day', '5 Day', '1 Month', '3 Month',
             'YTD', '1 Year', '3 Year', '5 Year', '10 Year']

# %%
df.head()
# Out:
#                        Real-Time   1 Day   5 Day 1 Month 3 Month     YTD  \
# Materials                  0.57%  -0.04%  -1.90%  -0.26%   5.10%  16.57%
# Information Technology     0.29%   0.35%  -1.66%   1.94%  10.05%  39.10%
# Financials                 0.28%   0.99%  -0.83%   2.34%  12.10%  24.79%
# Communication Services     0.23%   0.64%  -0.06%   2.55%   7.76%  28.02%
# Health Care               -0.02%   0.91%   0.39%   4.94%  10.72%  15.03%
#
#                         1 Year  3 Year   5 Year  10 Year
# Materials                6.34%  18.05%   18.65%   85.38%
# Information Technology  24.59%  93.82%  115.84%  326.63%
# Financials               9.98%  31.69%   49.62%  156.09%
# Communication Services  18.46%   8.80%   13.26%   57.91%
# Health Care              4.54%  46.05%   41.81%  219.03%

# %%
graph = df['1 Year'].replace('%', '', regex=True)
graph.astype(float).plot(kind='bar', figsize=(10,4))
plt.title('1 Year')
plt.grid()

# %%
graph = df['3 Year'].replace('%', '', regex=True)
graph.astype(float).plot(kind='bar', figsize=(10,4))
plt.title('3 Year')
plt.grid()

# %%
graph = df['5 Year'].replace('%', '', regex=True)
graph.astype(float).plot(kind='bar', figsize=(10,4))
plt.title('5 Year')
plt.grid()

# %%
graph = df['10 Year'].replace('%', '', regex=True)
graph.astype(float).plot(kind='bar', figsize=(10,4))
plt.title('10 Year')
plt.grid()
