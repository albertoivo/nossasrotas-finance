# %% [markdown]
# # ALPHA VANTAGE USA SECTORS

# %% [markdown]
# ## Lendo JSON

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

API_URL = "https://www.alphavantage.co/query"

data = {
    "function": "SECTOR",
    "apikey": "1VI1L6694V2Q3CFA",
}

response = requests.get(API_URL, params=data)

info = response.json()

# %%
df = pd.DataFrame(info)
df.drop('Meta Data', axis=1, inplace=True)
df.drop('Information', inplace=True)
df.drop('Last Refreshed', inplace=True)

# %%
df.columns = ['Real-Time', '1 Day', '5 Day', '1 Month', '3 Month',
             'YTD', '1 Year', '3 Year', '5 Year', '10 Year']

# %%
df
# Out:
#                        Real-Time   1 Day   5 Day 1 Month 3 Month     YTD  \
# Financials                 2.00%   2.00%   2.85%   3.41%   9.54%  28.83%
# Energy                     1.97%   1.97%   3.74%   0.39%  -0.38%   5.03%
# Materials                  1.44%   1.44%   2.47%   0.97%   5.00%  20.23%
# Information Technology     1.08%   1.08%   2.45%   3.07%   9.35%  43.06%
# Health Care                0.88%   0.88%   1.13%   6.33%  10.14%  16.36%
# Consumer Discretionary     0.88%   0.87%   1.85%   1.21%  -0.29%  23.23%
# Industrials                0.86%   0.86%   2.29%  -0.12%   3.90%  26.92%
# Communication Services     0.00%  -0.01%   0.27%   2.44%   4.13%  28.87%
# Consumer Staples          -0.08%  -0.08%   0.24%   2.63%   2.17%  22.46%
# Utilities                 -0.49%  -0.49%  -0.91%   1.92%  -0.50%  17.99%
# Real Estate               -1.45%  -1.45%  -2.63%  -1.21%  -3.49%  20.24%
#
#                         1 Year   3 Year   5 Year  10 Year
# Financials              25.79%   29.70%   54.16%  164.07%
# Energy                  -3.98%  -20.28%  -19.87%    5.21%
# Materials               17.80%   18.20%   26.43%   94.49%
# Information Technology  35.77%   91.23%  126.37%  335.99%
# Health Care             10.68%   46.78%   44.52%  221.79%
# Consumer Discretionary  17.59%   44.23%   73.06%  312.73%
# Industrials             21.22%   25.03%   43.81%  180.66%
# Communication Services  23.35%    5.47%   19.14%   55.31%
# Consumer Staples        13.42%   20.26%   28.42%  129.69%
# Utilities               10.75%   31.09%   35.39%   97.82%
# Real Estate             10.78%   22.22%      NaN      NaN

# %%
graph = df['1 Year'].replace('%', '', regex=True)
graph.astype(float).plot(kind='bar', figsize=(10,4))
plt.title('1 Year')
plt.grid()

# %%
graph = df['3 Year'].replace('%', '', regex=True)
graph.astype(float).plot(kind='bar', figsize=(10,4))
plt.title('3 Year')
plt.grid()

# %%
graph = df['5 Year'].replace('%', '', regex=True)
graph.astype(float).plot(kind='bar', figsize=(10,4))
plt.title('5 Year')
plt.grid()

# %%
graph = df['10 Year'].replace('%', '', regex=True)
graph.astype(float).plot(kind='bar', figsize=(10,4))
plt.title('10 Year')
plt.grid()
