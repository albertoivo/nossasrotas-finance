# %% [markdown]
# # ALPHA VANTAGE USA SECTORS

# %%
from alpha_vantage.sectorperformance import SectorPerformances
import matplotlib.pyplot as plt

# %%
sp = SectorPerformances(key='1VI1L6694V2Q3CFA', output_format='pandas')

df, md = sp.get_sector()

# %%
df.columns = ['Real-Time', '1 Day', '5 Day', '1 Month', '3 Month',
             'YTD', '1 Year', '3 Year', '5 Year', '10 Year']

# %%
df.drop(labels='Real-Time', axis=1, inplace=True)

# %%
df['STD'] = df.std(axis=1)

# %%
df.sort_values(by='STD')
# Out:
#                          1 Day   5 Day  1 Month  3 Month     YTD  1 Year  \
# Real Estate             0.0076  0.0205   0.0299   0.0488  0.2167  0.1398
# Energy                 -0.0135 -0.0338  -0.0549  -0.0687  0.0514 -0.2061
# Communication Services -0.0080 -0.0349   0.0094   0.0038  0.2034  0.1172
# Materials              -0.0121 -0.0299  -0.0287   0.0165  0.1340 -0.0315
# Utilities               0.0005  0.0025   0.0100   0.0357  0.1358  0.1475
# Consumer Staples        0.0012 -0.0192   0.0148   0.0380  0.1669  0.1179
# Financials             -0.0022 -0.0389  -0.0142  -0.0074  0.1557 -0.0135
# Industrials            -0.0065 -0.0345  -0.0227  -0.0224  0.1775  0.0014
# Health Care            -0.0022 -0.0113  -0.0240   0.0218  0.0515  0.0232
# Information Technology -0.0168 -0.0436  -0.0046   0.0058  0.2736  0.1040
# Consumer Discretionary -0.0091 -0.0457  -0.0217  -0.0088  0.1940  0.0589
#
#                         3 Year  5 Year  10 Year       STD
# Real Estate                NaN     NaN      NaN  0.083044
# Energy                 -0.0817 -0.3611   0.1434  0.145089
# Communication Services -0.0769  0.0386   0.5474  0.191191
# Materials               0.1839  0.1682   1.0513  0.345374
# Utilities               0.1527  0.4511   1.0737  0.348666
# Consumer Staples        0.0861  0.3627   1.4085  0.452781
# Financials              0.4382  0.5292   1.6164  0.538852
# Industrials             0.2685  0.4312   2.0550  0.672113
# Health Care             0.2033  0.4950   2.2482  0.736670
# Information Technology  0.7959  1.1701   3.4154  1.126150
# Consumer Discretionary  0.4386  0.7933   3.6839  1.202363

# %%
df['1 Year'].plot(kind='bar', figsize=(10,4))
plt.title('1 Year')
plt.grid()

# %%
df['3 Year'].plot(kind='bar', figsize=(10,4))
plt.title('3 Year')
plt.grid()

# %%
df['5 Year'].plot(kind='bar', figsize=(10,4))
plt.title('5 Year')
plt.grid()

# %%
df['10 Year'].plot(kind='bar', figsize=(10,4))
plt.title('10 Year')
plt.grid()
