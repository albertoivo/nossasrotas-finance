# %% [markdown]
# # ALPHA VANTAGE USA SECTORS

# %%
from alpha_vantage.sectorperformance import SectorPerformances
import matplotlib.pyplot as plt

# %%
sp = SectorPerformances(key='1VI1L6694V2Q3CFA', output_format='pandas')

df, md = sp.get_sector()

# %%
df.columns = ['Real-Time', '1 Day', '5 Day', '1 Month', '3 Month',
             'YTD', '1 Year', '3 Year', '5 Year', '10 Year']

# %%
df.drop(labels='Real-Time', axis=1, inplace=True)

# %%
df['STD'] = df.std(axis=1)

# %%
df.sort_values(by='1 Year')
# Out:
#                          1 Day   5 Day  1 Month  3 Month     YTD  1 Year  \
# Energy                 -0.0035 -0.0052   0.0225   0.0259  0.0332 -0.0981
# Health Care             0.0040  0.0081   0.0707   0.0767  0.1345  0.0980
# Materials               0.0015 -0.0169   0.0350   0.0489  0.1747  0.1043
# Consumer Staples       -0.0014 -0.0021   0.0040   0.0145  0.2033  0.1243
# Financials              0.0076  0.0046   0.0474   0.1253  0.2516  0.1405
# Real Estate            -0.0054 -0.0122  -0.0545  -0.0210  0.2227  0.1530
# Utilities               0.0003  0.0020  -0.0205   0.0155  0.1856  0.1666
# Consumer Discretionary  0.0065 -0.0080  -0.0199   0.0013  0.2081  0.1720
# Industrials             0.0054 -0.0081   0.0527   0.0895  0.2667  0.1728
# Communication Services  0.0013 -0.0040   0.0335   0.0681  0.2748  0.2307
# Information Technology -0.0012 -0.0083   0.0569   0.0826  0.3936  0.3410
#
#                         3 Year  5 Year  10 Year       STD
# Energy                 -0.1772 -0.3213   0.0153  0.121496
# Health Care             0.4087  0.4394   2.2294  0.709885
# Materials               0.2148  0.1697   0.8934  0.279476
# Consumer Staples        0.2058  0.2595   1.2632  0.400901
# Financials              0.3442  0.5205   1.5255  0.479500
# Real Estate             0.2981     NaN      NaN  0.139812
# Utilities               0.3475  0.3769   1.1591  0.373356
# Consumer Discretionary  0.4568  0.7005   3.1836  1.027903
# Industrials             0.2937  0.3987   1.8694  0.586907
# Communication Services  0.1073  0.0937   0.6594  0.209527
# Information Technology  0.8845  1.1978   3.3176  1.069137

# %%
df.sort_values(by='3 Year')
# Out:
#                          1 Day   5 Day  1 Month  3 Month     YTD  1 Year  \
# Energy                 -0.0035 -0.0052   0.0225   0.0259  0.0332 -0.0981
# Communication Services  0.0013 -0.0040   0.0335   0.0681  0.2748  0.2307
# Consumer Staples       -0.0014 -0.0021   0.0040   0.0145  0.2033  0.1243
# Materials               0.0015 -0.0169   0.0350   0.0489  0.1747  0.1043
# Industrials             0.0054 -0.0081   0.0527   0.0895  0.2667  0.1728
# Real Estate            -0.0054 -0.0122  -0.0545  -0.0210  0.2227  0.1530
# Financials              0.0076  0.0046   0.0474   0.1253  0.2516  0.1405
# Utilities               0.0003  0.0020  -0.0205   0.0155  0.1856  0.1666
# Health Care             0.0040  0.0081   0.0707   0.0767  0.1345  0.0980
# Consumer Discretionary  0.0065 -0.0080  -0.0199   0.0013  0.2081  0.1720
# Information Technology -0.0012 -0.0083   0.0569   0.0826  0.3936  0.3410
#
#                         3 Year  5 Year  10 Year       STD
# Energy                 -0.1772 -0.3213   0.0153  0.121496
# Communication Services  0.1073  0.0937   0.6594  0.209527
# Consumer Staples        0.2058  0.2595   1.2632  0.400901
# Materials               0.2148  0.1697   0.8934  0.279476
# Industrials             0.2937  0.3987   1.8694  0.586907
# Real Estate             0.2981     NaN      NaN  0.139812
# Financials              0.3442  0.5205   1.5255  0.479500
# Utilities               0.3475  0.3769   1.1591  0.373356
# Health Care             0.4087  0.4394   2.2294  0.709885
# Consumer Discretionary  0.4568  0.7005   3.1836  1.027903
# Information Technology  0.8845  1.1978   3.3176  1.069137

# %%
df.sort_values(by='5 Year')
# Out:
#                          1 Day   5 Day  1 Month  3 Month     YTD  1 Year  \
# Energy                 -0.0035 -0.0052   0.0225   0.0259  0.0332 -0.0981
# Communication Services  0.0013 -0.0040   0.0335   0.0681  0.2748  0.2307
# Materials               0.0015 -0.0169   0.0350   0.0489  0.1747  0.1043
# Consumer Staples       -0.0014 -0.0021   0.0040   0.0145  0.2033  0.1243
# Utilities               0.0003  0.0020  -0.0205   0.0155  0.1856  0.1666
# Industrials             0.0054 -0.0081   0.0527   0.0895  0.2667  0.1728
# Health Care             0.0040  0.0081   0.0707   0.0767  0.1345  0.0980
# Financials              0.0076  0.0046   0.0474   0.1253  0.2516  0.1405
# Consumer Discretionary  0.0065 -0.0080  -0.0199   0.0013  0.2081  0.1720
# Information Technology -0.0012 -0.0083   0.0569   0.0826  0.3936  0.3410
# Real Estate            -0.0054 -0.0122  -0.0545  -0.0210  0.2227  0.1530
#
#                         3 Year  5 Year  10 Year       STD
# Energy                 -0.1772 -0.3213   0.0153  0.121496
# Communication Services  0.1073  0.0937   0.6594  0.209527
# Materials               0.2148  0.1697   0.8934  0.279476
# Consumer Staples        0.2058  0.2595   1.2632  0.400901
# Utilities               0.3475  0.3769   1.1591  0.373356
# Industrials             0.2937  0.3987   1.8694  0.586907
# Health Care             0.4087  0.4394   2.2294  0.709885
# Financials              0.3442  0.5205   1.5255  0.479500
# Consumer Discretionary  0.4568  0.7005   3.1836  1.027903
# Information Technology  0.8845  1.1978   3.3176  1.069137
# Real Estate             0.2981     NaN      NaN  0.139812

# %%
df.sort_values(by='10 Year')
# Out:
#                          1 Day   5 Day  1 Month  3 Month     YTD  1 Year  \
# Energy                 -0.0035 -0.0052   0.0225   0.0259  0.0332 -0.0981
# Communication Services  0.0013 -0.0040   0.0335   0.0681  0.2748  0.2307
# Materials               0.0015 -0.0169   0.0350   0.0489  0.1747  0.1043
# Utilities               0.0003  0.0020  -0.0205   0.0155  0.1856  0.1666
# Consumer Staples       -0.0014 -0.0021   0.0040   0.0145  0.2033  0.1243
# Financials              0.0076  0.0046   0.0474   0.1253  0.2516  0.1405
# Industrials             0.0054 -0.0081   0.0527   0.0895  0.2667  0.1728
# Health Care             0.0040  0.0081   0.0707   0.0767  0.1345  0.0980
# Consumer Discretionary  0.0065 -0.0080  -0.0199   0.0013  0.2081  0.1720
# Information Technology -0.0012 -0.0083   0.0569   0.0826  0.3936  0.3410
# Real Estate            -0.0054 -0.0122  -0.0545  -0.0210  0.2227  0.1530
#
#                         3 Year  5 Year  10 Year       STD
# Energy                 -0.1772 -0.3213   0.0153  0.121496
# Communication Services  0.1073  0.0937   0.6594  0.209527
# Materials               0.2148  0.1697   0.8934  0.279476
# Utilities               0.3475  0.3769   1.1591  0.373356
# Consumer Staples        0.2058  0.2595   1.2632  0.400901
# Financials              0.3442  0.5205   1.5255  0.479500
# Industrials             0.2937  0.3987   1.8694  0.586907
# Health Care             0.4087  0.4394   2.2294  0.709885
# Consumer Discretionary  0.4568  0.7005   3.1836  1.027903
# Information Technology  0.8845  1.1978   3.3176  1.069137
# Real Estate             0.2981     NaN      NaN  0.139812

# %%
df['1 Year'].plot(kind='bar', figsize=(10,4))
plt.title('1 Year')
plt.grid()

# %%
df['3 Year'].plot(kind='bar', figsize=(10,4))
plt.title('3 Year')
plt.grid()

# %%
df['5 Year'].plot(kind='bar', figsize=(10,4))
plt.title('5 Year')
plt.grid()

# %%
df['10 Year'].plot(kind='bar', figsize=(10,4))
plt.title('10 Year')
plt.grid()
