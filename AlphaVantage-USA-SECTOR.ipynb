# %% [markdown]
# # ALPHA VANTAGE USA SECTORS

# %%
from alpha_vantage.sectorperformance import SectorPerformances
import matplotlib.pyplot as plt

# %%
sp = SectorPerformances(key='1VI1L6694V2Q3CFA', output_format='pandas')

df, md = sp.get_sector()

# %%
df.columns = ['Real-Time', '1 Day', '5 Day', '1 Month', '3 Month',
             'YTD', '1 Year', '3 Year', '5 Year', '10 Year']

# %%
df.drop(labels='Real-Time', axis=1, inplace=True)

# %%
df['STD'] = df.std(axis=1)

# %%
df.sort_values(by='10 Year')
# Out:
#                          1 Day   5 Day  1 Month  3 Month     YTD  1 Year  \
# Energy                 -0.0051 -0.0090   0.0251   0.0213  0.0347 -0.1133
# Communication Services  0.0042  0.0137   0.0451   0.0706  0.2671  0.1933
# Materials              -0.0048  0.0086   0.0481   0.0585  0.1899  0.1122
# Utilities               0.0147 -0.0071  -0.0251   0.0289  0.1775  0.1385
# Consumer Staples        0.0086  0.0052   0.0081   0.0405  0.2063  0.0846
# Financials             -0.0057 -0.0012   0.0680   0.1116  0.2391  0.1140
# Industrials            -0.0040  0.0003   0.0590   0.0960  0.2652  0.1507
# Health Care             0.0011  0.0122   0.0603   0.0544  0.1019  0.0409
# Consumer Discretionary -0.0038 -0.0127   0.0006   0.0297  0.2118  0.1130
# Information Technology  0.0025  0.0187   0.0604   0.1187  0.3954  0.2864
# Real Estate             0.0107 -0.0082  -0.0326  -0.0117  0.2204  0.1451
#
#                         3 Year  5 Year  10 Year       STD
# Energy                 -0.1417 -0.3070   0.0149  0.114111
# Communication Services  0.1411  0.0824   0.6623  0.205536
# Materials               0.2493  0.2209   0.9560  0.296589
# Utilities               0.3559  0.3741   1.1498  0.370772
# Consumer Staples        0.2158  0.2786   1.2978  0.410569
# Financials              0.3648  0.5093   1.4825  0.468296
# Industrials             0.3023  0.4156   1.8773  0.589801
# Health Care             0.3554  0.4061   2.2012  0.706540
# Consumer Discretionary  0.4956  0.7421   3.2129  1.038584
# Information Technology  0.9256  1.2368   3.3051  1.065765
# Real Estate             0.2976     NaN      NaN  0.131930

# %%
df['1 Year'].plot(kind='bar', figsize=(10,4))
plt.title('1 Year')
plt.grid()

# %%
df['3 Year'].plot(kind='bar', figsize=(10,4))
plt.title('3 Year')
plt.grid()

# %%
df['5 Year'].plot(kind='bar', figsize=(10,4))
plt.title('5 Year')
plt.grid()

# %%
df['10 Year'].plot(kind='bar', figsize=(10,4))
plt.title('10 Year')
plt.grid()
