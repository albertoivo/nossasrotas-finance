# %% [markdown]
# # ALPHA VANTAGE USA SECTORS

# %% [markdown]
# ## Lendo JSON

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

API_URL = "https://www.alphavantage.co/query"

data = {
    "function": "SECTOR",
    "apikey": "1VI1L6694V2Q3CFA",
}

response = requests.get(API_URL, params=data)

info = response.json()

# %%
df = pd.DataFrame(info)
df.drop('Meta Data', axis=1, inplace=True)
df.drop('Information', inplace=True)
df.drop('Last Refreshed', inplace=True)

# %%
df
# Out:
#                        Real-Time   1 Day   5 Day 1 Month 3 Month     YTD  \
# Energy                     1.61%  -1.55%  -3.20%  -2.87%   0.64%   0.17%
# Financials                 1.17%  -1.32%  -1.91%   1.34%   9.77%  23.57%
# Industrials                0.99%  -1.10%  -3.10%  -0.85%   5.34%  23.61%
# Communication Services     0.92%  -0.08%  -0.33%   1.90%   5.98%  27.21%
# Health Care                0.83%  -0.21%  -0.59%   3.99%   9.03%  13.99%
# Materials                  0.81%  -0.67%  -1.34%  -0.22%   4.22%  16.61%
# Utilities                  0.55%   0.50%   0.06%  -2.36%   0.48%  18.19%
# Consumer Discretionary     0.51%  -1.01%  -0.91%  -1.29%   0.36%  20.77%
# Information Technology     0.44%  -0.85%  -1.94%   1.58%   8.27%  38.61%
# Consumer Staples           0.40%  -0.18%   0.87%   1.16%   2.14%  21.59%
# Real Estate                0.37%   0.74%   0.28%  -2.69%  -2.66%  22.69%
#
#                          1 Year   3 Year   5 Year  10 Year
# Energy                  -12.67%  -22.30%  -28.79%   -2.83%
# Financials                9.42%   30.40%   48.78%  148.36%
# Industrials              10.25%   24.07%   38.03%  175.29%
# Communication Services   17.80%    8.11%   11.64%   57.23%
# Health Care               4.05%   44.72%   40.74%  216.14%
# Materials                 8.24%   18.10%   20.41%   82.33%
# Utilities                13.10%   34.58%   35.33%  105.00%
# Consumer Discretionary   10.57%   46.23%   67.26%  312.23%
# Information Technology   26.78%   93.14%  116.06%  324.45%
# Consumer Staples         10.09%   22.76%   25.60%  126.84%
# Real Estate              12.98%   29.32%      NaN      NaN

# %%
df.columns = ['Real-Time', '1 Day', '5 Day', '1 Month', '3 Month',
             'YTD', '1 Year', '3 Year', '5 Year', '10 Year']

# %%
graph = df['1 Year'].replace('%', '', regex=True)
graph.astype(float).plot(kind='bar', figsize=(10,4))
plt.title('1 Year')
plt.grid()

# %%
graph = df['3 Year'].replace('%', '', regex=True)
graph.astype(float).plot(kind='bar', figsize=(10,4))
plt.title('3 Year')
plt.grid()

# %%
graph = df['5 Year'].replace('%', '', regex=True)
graph.astype(float).plot(kind='bar', figsize=(10,4))
plt.title('5 Year')
plt.grid()

# %%
graph = df['10 Year'].replace('%', '', regex=True)
graph.astype(float).plot(kind='bar', figsize=(10,4))
plt.title('10 Year')
plt.grid()
