# %% [markdown]
# # Correlação ETF dos EUA

# %%
import numpy as np
from long_short import correlacao, heatmap
import datetime

# %matplotlib inline

ds_yahoo = 'yahoo'

ytd = datetime.datetime.now().year - 1
start = datetime.datetime.now().replace(year=ytd)
end = datetime.datetime.now()

# %%
acoes = ['ARKW', 'IAU', 'IHI', 'NOBL', 'VGT', 'OGIG', 'ARKG']

# %% [markdown]
# ## Correlação do ano

# %%
correlacao_ano = correlacao(acoes, start)
heatmap(correlacao_ano)

# %%
correlacao_ano
# Out:
#           ARKW       IAU       IHI      NOBL       VGT      OGIG      ARKG
# ARKW  1.000000  0.118327  0.771698  0.774774  0.891052  0.949877  0.850510
# IAU   0.118327  1.000000  0.096108  0.087205  0.068574  0.095589  0.178410
# IHI   0.771698  0.096108  1.000000  0.914903  0.893224  0.803604  0.791097
# NOBL  0.774774  0.087205  0.914903  1.000000  0.911266  0.781225  0.752702
# VGT   0.891052  0.068574  0.893224  0.911266  1.000000  0.921326  0.796053
# OGIG  0.949877  0.095589  0.803604  0.781225  0.921326  1.000000  0.841815
# ARKG  0.850510  0.178410  0.791097  0.752702  0.796053  0.841815  1.000000
