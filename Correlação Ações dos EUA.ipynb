# %% [markdown]
# # Correlação Ações dos EUA

# %%
import numpy as np
from long_short import correlacao, heatmap
import datetime

# %matplotlib inline

ds_yahoo = 'yahoo'

ytd = datetime.datetime.now().month - 4
start = datetime.datetime.now().replace(month=ytd)
end = datetime.datetime.now()

# %%
acoes = ['AMZN', 'GOOGL', 'JNJ', 'LB', 'M', 'MSFT', 'ROST', 'V']

# %% [markdown]
# ## Correlação do ano

# %%
correlacao_ano = correlacao(acoes, start)
heatmap(correlacao_ano)

# %%
correlacao_ano
# Out:
#            BBDC4.SA  BBDC3.SA  ITUB4.SA  ITUB3.SA  BBAS3.SA  SANB3.SA  \
# BBDC4.SA   1.000000  0.932024  0.829012  0.798111  0.734297  0.527748
# BBDC3.SA   0.932024  1.000000  0.805722  0.793372  0.694950  0.514564
# ITUB4.SA   0.829012  0.805722  1.000000  0.918325  0.655359  0.519111
# ITUB3.SA   0.798111  0.793372  0.918325  1.000000  0.658067  0.459022
# BBAS3.SA   0.734297  0.694950  0.655359  0.658067  1.000000  0.440430
# SANB3.SA   0.527748  0.514564  0.519111  0.459022  0.440430  1.000000
# SANB11.SA  0.857977  0.855614  0.892898  0.860144  0.465800  0.361800
# SANB4.SA   0.601125  0.565739  0.630798  0.614549  0.532794  0.546408
# ITSA3.SA   0.604452  0.603012  0.652163  0.612664  0.466684  0.451959
# ITSA4.SA   0.796033  0.795363  0.911083  0.863068  0.663393  0.491972
# CIEL3.SA   0.244687  0.243227  0.199485  0.237582  0.318004  0.168997
# B3SA3.SA   0.540963  0.577859  0.525168  0.495137  0.556405  0.381723
# ...
