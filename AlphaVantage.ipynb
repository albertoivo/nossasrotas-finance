# %% [markdown]
# # Lendo o JSON (Dumb way)

# %%
import requests

API_URL = "https://www.alphavantage.co/query"

data = {
    "function": "TIME_SERIES_DAILY",
    "symbol": "PETR4.SA",
    "outputsize": "compact",
    "datatype": "json",
    "apikey": "1VI1L6694V2Q3CFA",
}

response = requests.get(API_URL, params=data)

response.json()
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'PETR4.SA',
#   '3. Last Refreshed': '2019-06-18',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2019-06-18': {'1. open': '27.3000',
#    '2. high': '27.5200',
#    '3. low': '27.2500',
#    '4. close': '27.4200',
#    '5. volume': '18874400'},
#   '2019-06-17': {'1. open': '27.0800',
#    '2. high': '27.4300',
#    '3. low': '26.9600',
#    '4. close': '27.1100',
#    '5. volume': '48741000'},
#   '2019-06-14': {'1. open': '27.2000',
#    '2. high': '27.2500',
#    '3. low': '26.9000',
#    '4. close': '27.0600',
#    '5. volume': '42802400'},
#   '2019-06-13': {'1. open': '27.1500',
#    '2. high': '27.3900',
#    '3. low': '27.0800',
#    '4. close': '27.1800',
#    '5. volume': '48981600'},
#   '2019-06-12': {'1. open': '27.0200',
#    '2. high': '27.1200',
#    '3. low': '26.6400',
#    '4. close': '26.8500',
#    '5. volume': '43392200'},
#   '2019-06-11': {'1. open': '26.8900',
#    '2. high': '27.2900',
#    '3. low': '26.7100',
#    '4. close': '27.1600',
#    '5. volume': '52437000'},
#   '2019-06-10': {'1. open': '26.6000',
#    '2. high': '26.8900',
#    '3. low': '26.5200',
#    '4. close': '26.6500',
#    '5. volume': '39666800'},
#   '2019-06-07': {'1. open': '26.6900',
#    '2. high': '26.8300',
#    '3. low': '26.3700',
#    '4. close': '26.7600',
#    '5. volume': '52235500'},
#   '2019-06-06': {'1. open': '26.1700',
#    '2. high': '26.6300',
#    '3. low': '25.7200',
#    '4. close': '26.2800',
#    '5. volume': '87836900'},
#   '2019-06-05': {'1. open': '26.1800',
#    '2. high': '26.2900',
#    '3. low': '25.5600',
#    '4. close': '25.8600',
#    '5. volume': '65282100'},
#   '2019-06-04': {'1. open': '26.2900',
#    '2. high': '26.3700',
#    '3. low': '26.0300',
#    '4. close': '26.2000',
#    '5. volume': '37331100'},
#   '2019-06-03': {'1. open': '25.8800',
#    '2. high': '26.3200',
#    '3. low': '25.8500',
#    '4. close': '25.9900',
#    '5. volume': '53470600'},
#   '2019-05-31': {'1. open': '25.7900',
#    '2. high': '26.2700',
#    '3. low': '25.4200',
#    '4. close': '25.5500',
#    '5. volume': '63137200'},
#   '2019-05-30': {'1. open': '26.5100',
#    '2. high': '26.8600',
#    '3. low': '25.9900',
#    '4. close': '26.1500',
#    '5. volume': '71847200'},
#   '2019-05-29': {'1. open': '26.4900',
#    '2. high': '26.7100',
#    '3. low': '26.2600',
#    '4. close': '26.5000',
#    '5. volume': '43124400'},
#   '2019-05-28': {'1. open': '26.1300',
#    '2. high': '26.8000',
#    '3. low': '26.1300',
#    '4. close': '26.8000',
#    '5. volume': '60774600'},
#   '2019-05-27': {'1. open': '26.3000',
#    '2. high': '26.5400',
#    '3. low': '26.1700',
#    '4. close': '26.2400',
#    '5. volume': '33892000'},
#   '2019-05-24': {'1. open': '26.1500',
#    '2. high': '26.3600',
#    '3. low': '25.9300',
#    '4. close': '26.0900',
#    '5. volume': '35915100'},
#   '2019-05-23': {'1. open': '25.9000',
#    '2. high': '25.9200',
#    '3. low': '25.5200',
#    '4. close': '25.8400',
#    '5. volume': '49527400'},
#   '2019-05-22': {'1. open': '26.3400',
#    '2. high': '26.4700',
#    '3. low': '25.9600',
#    '4. close': '26.2900',
#    '5. volume': '48439300'},
#   '2019-05-21': {'1. open': '25.7000',
#    '2. high': '26.4900',
#    '3. low': '25.4200',
#    '4. close': '26.4900',
#    '5. volume': '57846700'},
#   '2019-05-20': {'1. open': '24.6800',
#    '2. high': '25.5200',
#    '3. low': '24.6400',
#    '4. close': '25.5200',
#    '5. volume': '54472000'},
#   '2019-05-17': {'1. open': '25.0500',
#    '2. high': '25.4200',
#    '3. low': '24.4700',
#    '4. close': '24.6800',
#    '5. volume': '67291200'},
#   '2019-05-16': {'1. open': '25.7700',
#    '2. high': '26.0400',
#    '3. low': '25.2400',
#    '4. close': '25.2700',
#    '5. volume': '46502200'},
#   '2019-05-15': {'1. open': '25.7400',
#    '2. high': '25.8900',
#    '3. low': '25.6600',
#    '4. close': '25.8800',
#    '5. volume': '37053900'},
#   '2019-05-14': {'1. open': '26.1700',
#    '2. high': '26.2300',
#    '3. low': '25.8500',
#    '4. close': '26.0000',
#    '5. volume': '34968600'},
#   '2019-05-13': {'1. open': '26.2100',
#    '2. high': '26.4700',
#    '3. low': '25.8200',
#    '4. close': '25.9000',
#    '5. volume': '43146100'},
#   '2019-05-10': {'1. open': '26.8700',
#    '2. high': '26.9200',
#    '3. low': '26.4200',
#    '4. close': '26.6800',
#    '5. volume': '33336000'},
#   '2019-05-09': {'1. open': '27.1000',
#    '2. high': '27.1200',
#    '3. low': '26.6400',
#    '4. close': '26.8300',
#    '5. volume': '46663300'},
#   '2019-05-08': {'1. open': '26.3100',
#    '2. high': '27.4700',
#    '3. low': '26.2900',
#    '4. close': '27.3700',
#    '5. volume': '71780300'},
#   '2019-05-07': {'1. open': '26.6500',
#    '2. high': '26.6600',
#    '3. low': '26.1200',
#    '4. close': '26.3500',
#    '5. volume': '52454400'},
#   '2019-05-06': {'1. open': '26.3900',
#    '2. high': '26.7700',
#    '3. low': '26.3600',
#    '4. close': '26.7700',
#    '5. volume': '31715900'},
#   '2019-05-03': {'1. open': '26.9000',
#    '2. high': '27.0700',
#    '3. low': '26.8500',
#    '4. close': '26.8500',
#    '5. volume': '33334800'},
#   '2019-05-02': {'1. open': '26.8000',
#    '2. high': '26.8200',
#    '3. low': '26.5200',
#    '4. close': '26.7300',
#    '5. volume': '37820300'},
#   '2019-04-30': {'1. open': '27.5200',
#    '2. high': '27.6600',
#    '3. low': '26.9800',
#    '4. close': '27.1100',
#    '5. volume': '39570700'},
#   '2019-04-29': {'1. open': '27.5500',
#    '2. high': '27.6200',
#    '3. low': '27.3400',
#    '4. close': '27.3700',
#    '5. volume': '27689800'},
#   '2019-04-26': {'1. open': '27.6800',
#    '2. high': '27.7700',
#    '3. low': '27.0600',
#    '4. close': '27.2500',
#    '5. volume': '52616600'},
#   '2019-04-25': {'1. open': '27.4500',
#    '2. high': '28.0700',
#    '3. low': '27.4300',
#    '4. close': '27.8000',
#    '5. volume': '55201700'},
#   '2019-04-24': {'1. open': '27.7200',
#    '2. high': '27.8900',
#    '3. low': '27.2100',
#    '4. close': '27.6000',
#    '5. volume': '57704700'},
#   '2019-04-23': {'1. open': '27.7200',
#    '2. high': '28.0000',
#    '3. low': '27.6800',
#    '4. close': '27.6800',
#    '5. volume': '52199500'},
#   '2019-04-22': {'1. open': '27.6900',
#    '2. high': '27.8900',
#    '3. low': '27.3200',
#    '4. close': '27.4400',
#    '5. volume': '45321900'},
#   '2019-04-18': {'1. open': '27.3600',
#    '2. high': '27.8900',
#    '3. low': '27.2500',
#    '4. close': '27.6000',
#    '5. volume': '100942100'},
#   '2019-04-17': {'1. open': '27.1200',
#    '2. high': '27.3400',
#    '3. low': '26.2200',
#    '4. close': '26.7500',
#    '5. volume': '103988400'},
#   '2019-04-16': {'1. open': '25.9500',
#    '2. high': '27.0600',
#    '3. low': '25.6300',
#    '4. close': '26.7200',
#    '5. volume': '95149300'},
#   '2019-04-15': {'1. open': '26.3500',
#    '2. high': '26.5800',
#    '3. low': '25.5500',
#    '4. close': '25.9300',
#    '5. volume': '117567200'},
#   '2019-04-12': {'1. open': '26.4700',
#    '2. high': '26.9700',
#    '3. low': '25.5700',
#    '4. close': '25.8300',
#    '5. volume': '227307600'},
#   '2019-04-11': {'1. open': '28.7000',
#    '2. high': '28.7000',
#    '3. low': '27.8700',
#    '4. close': '28.0000',
#    '5. volume': '56126400'},
#   '2019-04-10': {'1. open': '29.5500',
#    '2. high': '29.5700',
#    '3. low': '28.7800',
#    '4. close': '28.7800',
#    '5. volume': '62005200'},
#   '2019-04-09': {'1. open': '29.0300',
#    '2. high': '29.2400',
#    '3. low': '28.6700',
#    '4. close': '29.1600',
#    '5. volume': '43863700'},
#   '2019-04-08': {'1. open': '29.0600',
#    '2. high': '29.3900',
#    '3. low': '28.9800',
#    '4. close': '29.2500',
#    '5. volume': '55270000'},
#   '2019-04-05': {'1. open': '28.5400',
#    '2. high': '28.8900',
#    '3. low': '28.2100',
#    '4. close': '28.7800',
#    '5. volume': '54708900'},
#   '2019-04-04': {'1. open': '27.7700',
#    '2. high': '28.4700',
#    '3. low': '27.3700',
#    '4. close': '28.4700',
#    '5. volume': '52248100'},
#   '2019-04-03': {'1. open': '28.5300',
#    '2. high': '28.5600',
#    '3. low': '27.5400',
#    '4. close': '27.5400',
#    '5. volume': '55120900'},
#   '2019-04-02': {'1. open': '28.1400',
#    '2. high': '28.3000',
#    '3. low': '27.8600',
#    '4. close': '28.2900',
#    '5. volume': '38460600'},
#   '2019-04-01': {'1. open': '28.4000',
#    '2. high': '28.4200',
#    '3. low': '27.8700',
#    '4. close': '28.0000',
#    '5. volume': '42289800'},
#   '2019-03-29': {'1. open': '28.4500',
#    '2. high': '28.5300',
#    '3. low': '27.7400',
#    '4. close': '28.0600',
#    '5. volume': '51587400'},
#   '2019-03-28': {'1. open': '27.2500',
#    '2. high': '28.0600',
#    '3. low': '26.9500',
#    '4. close': '28.0600',
#    '5. volume': '69412700'},
#   '2019-03-27': {'1. open': '28.2100',
#    '2. high': '28.2100',
#    '3. low': '27.3400',
#    '4. close': '27.3400',
#    '5. volume': '66415400'},
#   '2019-03-26': {'1. open': '27.7400',
#    '2. high': '28.6800',
#    '3. low': '27.7200',
#    '4. close': '28.6300',
#    '5. volume': '91549100'},
#   '2019-03-25': {'1. open': '26.8300',
#    '2. high': '27.5900',
#    '3. low': '26.8200',
#    '4. close': '27.3400',
#    '5. volume': '104772900'},
#   '2019-03-22': {'1. open': '27.9400',
#    '2. high': '28.1400',
#    '3. low': '27.0000',
#    '4. close': '27.0000',
#    '5. volume': '104731100'},
#   '2019-03-21': {'1. open': '28.8400',
#    '2. high': '28.9700',
#    '3. low': '27.9200',
#    '4. close': '28.5600',
#    '5. volume': '80121300'},
#   '2019-03-20': {'1. open': '29.2000',
#    '2. high': '29.6000',
#    '3. low': '28.9000',
#    '4. close': '28.9700',
#    '5. volume': '68878000'},
#   '2019-03-19': {'1. open': '28.8500',
#    '2. high': '29.5000',
#    '3. low': '28.6000',
#    '4. close': '29.2000',
#    '5. volume': '69423600'},
#   '2019-03-18': {'1. open': '28.3500',
#    '2. high': '28.7900',
#    '3. low': '28.2600',
#    '4. close': '28.7400',
#    '5. volume': '91920600'},
#   '2019-03-15': {'1. open': '28.1600',
#    '2. high': '28.3900',
#    '3. low': '28.1100',
#    '4. close': '28.2500',
#    '5. volume': '61041100'},
#   '2019-03-14': {'1. open': '28.1500',
#    '2. high': '28.2000',
#    '3. low': '27.9100',
#    '4. close': '28.1900',
#    '5. volume': '42777800'},
#   '2019-03-13': {'1. open': '27.5900',
#    '2. high': '28.1300',
#    '3. low': '27.5200',
#    '4. close': '28.1000',
#    '5. volume': '61057200'},
#   '2019-03-12': {'1. open': '27.7900',
#    '2. high': '27.9600',
#    '3. low': '27.2500',
#    '4. close': '27.5000',
#    '5. volume': '64287300'},
#   '2019-03-11': {'1. open': '27.0200',
#    '2. high': '27.7800',
#    '3. low': '27.0100',
#    '4. close': '27.7500',
#    '5. volume': '66742800'},
#   '2019-03-08': {'1. open': '26.4900',
#    '2. high': '26.7500',
#    '3. low': '26.2200',
#    '4. close': '26.6700',
#    '5. volume': '49564400'},
#   '2019-03-07': {'1. open': '26.8000',
#    '2. high': '26.9100',
#    '3. low': '26.4900',
#    '4. close': '26.7700',
#    '5. volume': '32835300'},
#   '2019-03-06': {'1. open': '26.5500',
#    '2. high': '26.7600',
#    '3. low': '26.4700',
#    '4. close': '26.7600',
#    '5. volume': '18423400'},
#   '2019-03-01': {'1. open': '27.1400',
#    '2. high': '27.2500',
#    '3. low': '26.6300',
#    '4. close': '26.7000',
#    '5. volume': '41978700'},
#   '2019-02-28': {'1. open': '27.7200',
#    '2. high': '27.7500',
#    '3. low': '26.6000',
#    '4. close': '27.0600',
#    '5. volume': '93065100'},
#   '2019-02-27': {'1. open': '26.8400',
#    '2. high': '27.2500',
#    '3. low': '26.6300',
#    '4. close': '27.0800',
#    '5. volume': '49131400'},
#   '2019-02-26': {'1. open': '26.7600',
#    '2. high': '27.1400',
#    '3. low': '26.5700',
#    '4. close': '26.5800',
#    '5. volume': '46504200'},
#   '2019-02-25': {'1. open': '27.0000',
#    '2. high': '27.0300',
#    '3. low': '26.6300',
#    '4. close': '26.7000',
#    '5. volume': '54190800'},
#   '2019-02-22': {'1. open': '27.5500',
#    '2. high': '27.7000',
#    '3. low': '27.1300',
#    '4. close': '27.1300',
#    '5. volume': '36602000'},
#   '2019-02-21': {'1. open': '27.1800',
#    '2. high': '27.4900',
#    '3. low': '26.8200',
#    '4. close': '27.4000',
#    '5. volume': '46559400'},
#   '2019-02-20': {'1. open': '27.5000',
#    '2. high': '27.6600',
#    '3. low': '26.8700',
#    '4. close': '27.0400',
#    '5. volume': '55114500'},
#   '2019-02-19': {'1. open': '26.8600',
#    '2. high': '27.4000',
#    '3. low': '26.8400',
#    '4. close': '27.3800',
#    '5. volume': '58041900'},
#   '2019-02-18': {'1. open': '26.5900',
#    '2. high': '26.7900',
#    '3. low': '26.4100',
#    '4. close': '26.7600',
#    '5. volume': '43379000'},
#   '2019-02-15': {'1. open': '26.8600',
#    '2. high': '27.0200',
#    '3. low': '26.7100',
#    '4. close': '26.8400',
#    '5. volume': '63841800'},
#   '2019-02-14': {'1. open': '26.1700',
#    '2. high': '26.9500',
#    '3. low': '26.0000',
#    '4. close': '26.9500',
#    '5. volume': '81125500'},
#   '2019-02-13': {'1. open': '26.0200',
#    '2. high': '26.2100',
#    '3. low': '25.8500',
#    '4. close': '26.0500',
#    '5. volume': '69042200'},
#   '2019-02-12': {'1. open': '25.3200',
#    '2. high': '25.8500',
#    '3. low': '25.2300',
#    '4. close': '25.7200',
#    '5. volume': '72467200'},
#   '2019-02-11': {'1. open': '25.1700',
#    '2. high': '25.1700',
#    '3. low': '24.5400',
#    '4. close': '24.8400',
#    '5. volume': '39617300'},
#   '2019-02-08': {'1. open': '24.8000',
#    '2. high': '25.2800',
#    '3. low': '24.7300',
#    '4. close': '25.1300',
#    '5. volume': '40153900'},
#   '2019-02-07': {'1. open': '25.6000',
#    '2. high': '25.8500',
#    '3. low': '24.6600',
#    '4. close': '25.0900',
#    '5. volume': '55614100'},
#   '2019-02-06': {'1. open': '25.8000',
#    '2. high': '25.8400',
#    '3. low': '25.3200',
#    '4. close': '25.4900',
#    '5. volume': '64527000'},
#   '2019-02-05': {'1. open': '25.9100',
#    '2. high': '26.1000',
#    '3. low': '25.8100',
#    '4. close': '26.0800',
#    '5. volume': '40989100'},
#   '2019-02-04': {'1. open': '25.8400',
#    '2. high': '26.1200',
#    '3. low': '25.6000',
#    '4. close': '26.0300',
#    '5. volume': '53874900'},
#   '2019-02-01': {'1. open': '25.5000',
#    '2. high': '25.8500',
#    '3. low': '25.3700',
#    '4. close': '25.8000',
#    '5. volume': '47957400'},
#   '2019-01-31': {'1. open': '25.8700',
#    '2. high': '25.9600',
#    '3. low': '25.5600',
#    '4. close': '25.5800',
#    '5. volume': '63253600'},
#   '2019-01-30': {'1. open': '25.8100',
#    '2. high': '25.9300',
#    '3. low': '25.4700',
#    '4. close': '25.6200',
#    '5. volume': '62607500'},
#   '2019-01-29': {'1. open': '25.2500',
#    '2. high': '25.5600',
#    '3. low': '25.1100',
#    '4. close': '25.3700',
#    '5. volume': '59419200'},
#   '2019-01-28': {'1. open': '25.2900',
#    '2. high': '25.5300',
#    '3. low': '24.7400',
#    '4. close': '24.7700',
#    '5. volume': '65079900'},
#   '2019-01-24': {'1. open': '25.4000',
#    '2. high': '25.5400',
#    '3. low': '25.3200',
#    '4. close': '25.5400',
#    '5. volume': '40109000'},
#   '2019-01-23': {'1. open': '25.3300',
#    '2. high': '25.5400',
#    '3. low': '25.1600',
#    '4. close': '25.4300',
#    '5. volume': '52931600'}}}

# %% [markdown]
# # Acessando a API

# %%
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
import matplotlib.pyplot as plt

ts = TimeSeries(key='1VI1L6694V2Q3CFA', output_format='pandas')
ti = TechIndicators(key='1VI1L6694V2Q3CFA', output_format='pandas')

# data, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='full')
data, meta_data = ts.get_daily('ITUB4.SA')

data_2, meta_data_2 = ti.get_rsi('ITUB4.SA')

# %%
data.head()
# Out:
#             1. open  2. high  3. low  4. close   5. volume
# date
# 2019-01-23    37.45    37.69   36.96     37.54  27249900.0
# 2019-01-24    37.35    37.73   37.24     37.49  21283100.0
# 2019-01-28    37.07    38.35   37.07     38.16  22555600.0
# 2019-01-29    38.40    38.55   37.88     37.88  15826000.0
# 2019-01-30    38.22    38.41   37.40     38.12  19386900.0

# %%
data['4. close'].plot(figsize=(17,8))
#plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()
