# %% [markdown]
# # ALPHA VANTAGE

# %% [markdown]
# # Lendo o JSON (Dumb way)

# %%
import requests

API_URL = "https://www.alphavantage.co/query"

data = {
    "function": "TIME_SERIES_DAILY_ADJUSTED",
    "symbol": "ITUB4.SA",
    "outputsize": "full",
    "datatype": "json",
    "apikey": "1VI1L6694V2Q3CFA",
}

response = requests.get(API_URL, params=data)

info = response.json()

# %%
dict = info['Time Series (Daily)']
for d in dict:
    div = dict[d]['7. dividend amount']
    cof = dict[d]['8. split coefficient']
    if (div != '0.0000' or cof != '1.0000'):
        print('{} - {}'.format(div, cof))

# %% [markdown]
# # Acessando a API

# %%
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
import matplotlib.pyplot as plt

# %%
ts = TimeSeries(key='1VI1L6694V2Q3CFA', output_format='pandas', )

intraday, meta_intra = ts.get_intraday(symbol='ITUB4.SA', interval='5min', outputsize='compact')
daily, meta_daily = ts.get_daily('ITUB4.SA', outputsize='compact')

# %%
intraday['4. close'].plot(figsize=(17,6));

# %%
daily['4. close'].plot(figsize=(17,6));

# %%
ti = TechIndicators(key='1VI1L6694V2Q3CFA', output_format='pandas')
rsi, meta_rsi = ti.get_rsi('ITUB4.SA')

# %%
rsi.plot(figsize=(17,8))
#plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()

# %%
rsi.tail()
# Out:
#                 RSI
# date
# 2019-06-12  54.4900
# 2019-06-13  49.9898
# 2019-06-14  50.0598
# 2019-06-17  49.7664
# 2019-06-18  54.4076

# %%
print('first') if 1 < 2 else print('second')
# Out:
# first
