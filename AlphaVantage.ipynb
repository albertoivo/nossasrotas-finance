# %% [markdown]
# # ALPHA VANTAGE

# %% [markdown]
# # Lendo o JSON

# %%
import requests
import pandas as pd

API_URL = "https://www.alphavantage.co/query"

data = {
    "function": "TIME_SERIES_DAILY_ADJUSTED",
    "symbol": "ITUB4.SA",
    "outputsize": "full",
    "datatype": "json",
    "apikey": "1VI1L6694V2Q3CFA",
}

response = requests.get(API_URL, params=data)

info = response.json()

# %%
try:
    print(info['Time Series (Daily)']['2019-12-01'])
except KeyError as ke:
    print('nao tem info para essa data ' + str(ke))
# Out:
# nao tem info para essa data '2019-12-01'

# %%
info
# Out:
# {'Meta Data': {'1. Information': 'Daily Time Series with Splits and Dividend Events',
#   '2. Symbol': 'ITUB4.SA',
#   '3. Last Refreshed': '2019-12-04',
#   '4. Output Size': 'Full size',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2019-12-04': {'1. open': '35.3900',
#    '2. high': '36.5700',
#    '3. low': '35.3000',
#    '4. close': '36.4200',
#    '5. adjusted close': '36.4200',
#    '6. volume': '25791900',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-12-03': {'1. open': '35.5900',
#    '2. high': '35.7100',
#    '3. low': '34.9100',
#    '4. close': '35.2900',
#    '5. adjusted close': '35.2900',
#    '6. volume': '15999200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-12-02': {'1. open': '34.9200',
#    '2. high': '35.5200',
#    '3. low': '34.8400',
#    '4. close': '35.2800',
#    '5. adjusted close': '35.2800',
#    '6. volume': '16447900',
#    '7. dividend amount': '0.0150',
#    '8. split coefficient': '1.0000'},
#   '2019-11-29': {'1. open': '34.6700',
#    '2. high': '34.8300',
#    '3. low': '34.3000',
#    '4. close': '34.8000',
#    '5. adjusted close': '34.7850',
#    '6. volume': '16530900',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-28': {'1. open': '34.4500',
#    '2. high': '34.7000',
#    '3. low': '34.0200',
#    '4. close': '34.6000',
#    '5. adjusted close': '34.5851',
#    '6. volume': '15850200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-27': {'1. open': '34.7000',
#    '2. high': '34.9300',
#    '3. low': '34.2600',
#    '4. close': '34.7000',
#    '5. adjusted close': '34.6850',
#    '6. volume': '19366600',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-26': {'1. open': '35.0000',
#    '2. high': '35.0900',
#    '3. low': '34.3500',
#    '4. close': '34.5000',
#    '5. adjusted close': '34.4851',
#    '6. volume': '26176400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-25': {'1. open': '35.7900',
#    '2. high': '35.9000',
#    '3. low': '35.0100',
#    '4. close': '35.2200',
#    '5. adjusted close': '35.2048',
#    '6. volume': '15202500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-22': {'1. open': '35.2600',
#    '2. high': '35.8300',
#    '3. low': '35.2100',
#    '4. close': '35.7300',
#    '5. adjusted close': '35.7146',
#    '6. volume': '16433000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-21': {'1. open': '35.1300',
#    '2. high': '35.5000',
#    '3. low': '35.0300',
#    '4. close': '35.4900',
#    '5. adjusted close': '35.4747',
#    '6. volume': '26063800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-19': {'1. open': '35.5000',
#    '2. high': '35.6000',
#    '3. low': '34.8500',
#    '4. close': '35.1300',
#    '5. adjusted close': '35.1149',
#    '6. volume': '17887600',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-18': {'1. open': '36.0000',
#    '2. high': '36.2000',
#    '3. low': '35.4800',
#    '4. close': '35.5200',
#    '5. adjusted close': '35.5047',
#    '6. volume': '13345400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-14': {'1. open': '35.5000',
#    '2. high': '35.7900',
#    '3. low': '35.1600',
#    '4. close': '35.6800',
#    '5. adjusted close': '35.6646',
#    '6. volume': '14012300',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-13': {'1. open': '35.6700',
#    '2. high': '35.8400',
#    '3. low': '35.1800',
#    '4. close': '35.4500',
#    '5. adjusted close': '35.4347',
#    '6. volume': '17688000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-12': {'1. open': '36.0200',
#    '2. high': '36.2900',
#    '3. low': '35.4300',
#    '4. close': '35.8100',
#    '5. adjusted close': '35.7946',
#    '6. volume': '19644000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-11': {'1. open': '36.2000',
#    '2. high': '36.8000',
#    '3. low': '35.9000',
#    '4. close': '36.4300',
#    '5. adjusted close': '36.4143',
#    '6. volume': '17480000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-08': {'1. open': '36.3600',
#    '2. high': '36.7800',
#    '3. low': '36.0200',
#    '4. close': '36.2700',
#    '5. adjusted close': '36.2544',
#    '6. volume': '15088000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-07': {'1. open': '36.7800',
#    '2. high': '36.9500',
#    '3. low': '36.5700',
#    '4. close': '36.8200',
#    '5. adjusted close': '36.8041',
#    '6. volume': '15689500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-06': {'1. open': '37.1000',
#    '2. high': '37.3600',
#    '3. low': '36.5700',
#    '4. close': '36.6000',
#    '5. adjusted close': '36.5842',
#    '6. volume': '19030900',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-05': {'1. open': '37.6400',
#    '2. high': '37.9900',
#    '3. low': '36.8000',
#    '4. close': '37.1000',
#    '5. adjusted close': '37.0840',
#    '6. volume': '46982800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-04': {'1. open': '36.4500',
#    '2. high': '36.7500',
#    '3. low': '36.2400',
#    '4. close': '36.4700',
#    '5. adjusted close': '36.4543',
#    '6. volume': '10065400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-11-01': {'1. open': '36.6600',
#    '2. high': '36.9100',
#    '3. low': '35.9100',
#    '4. close': '36.3500',
#    '5. adjusted close': '36.3343',
#    '6. volume': '18958400',
#    '7. dividend amount': '0.0150',
#    '8. split coefficient': '1.0000'},
#   '2019-10-31': {'1. open': '36.3000',
#    '2. high': '36.6700',
#    '3. low': '35.6800',
#    '4. close': '36.2300',
#    '5. adjusted close': '36.1994',
#    '6. volume': '26038300',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-30': {'1. open': '36.4700',
#    '2. high': '37.0000',
#    '3. low': '35.9100',
#    '4. close': '36.8700',
#    '5. adjusted close': '36.8388',
#    '6. volume': '23575800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-29': {'1. open': '37.0900',
#    '2. high': '37.2300',
#    '3. low': '36.5700',
#    '4. close': '36.6400',
#    '5. adjusted close': '36.6090',
#    '6. volume': '16557800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-28': {'1. open': '36.6500',
#    '2. high': '37.5300',
#    '3. low': '36.5300',
#    '4. close': '37.3000',
#    '5. adjusted close': '37.2685',
#    '6. volume': '20976400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-25': {'1. open': '36.5500',
#    '2. high': '37.1300',
#    '3. low': '36.3400',
#    '4. close': '36.8000',
#    '5. adjusted close': '36.7689',
#    '6. volume': '18955500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-24': {'1. open': '36.4600',
#    '2. high': '36.8300',
#    '3. low': '36.1300',
#    '4. close': '36.5600',
#    '5. adjusted close': '36.5291',
#    '6. volume': '27250700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-23': {'1. open': '35.5900',
#    '2. high': '36.7500',
#    '3. low': '35.5100',
#    '4. close': '36.3900',
#    '5. adjusted close': '36.3593',
#    '6. volume': '34380200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-22': {'1. open': '34.7700',
#    '2. high': '35.8900',
#    '3. low': '34.6700',
#    '4. close': '35.8800',
#    '5. adjusted close': '35.8497',
#    '6. volume': '35538100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-21': {'1. open': '34.2600',
#    '2. high': '34.8700',
#    '3. low': '33.9900',
#    '4. close': '34.8000',
#    '5. adjusted close': '34.7706',
#    '6. volume': '16378000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-18': {'1. open': '34.6200',
#    '2. high': '34.6200',
#    '3. low': '34.1500',
#    '4. close': '34.2400',
#    '5. adjusted close': '34.2111',
#    '6. volume': '11418100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-17': {'1. open': '34.8500',
#    '2. high': '35.1300',
#    '3. low': '34.3200',
#    '4. close': '34.6500',
#    '5. adjusted close': '34.6207',
#    '6. volume': '17054300',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-16': {'1. open': '34.4700',
#    '2. high': '34.9800',
#    '3. low': '33.8300',
#    '4. close': '34.8600',
#    '5. adjusted close': '34.8305',
#    '6. volume': '17662300',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-15': {'1. open': '34.4800',
#    '2. high': '34.6400',
#    '3. low': '34.1900',
#    '4. close': '34.3700',
#    '5. adjusted close': '34.3410',
#    '6. volume': '15976800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-14': {'1. open': '33.8100',
#    '2. high': '34.5400',
#    '3. low': '33.7200',
#    '4. close': '34.4500',
#    '5. adjusted close': '34.4209',
#    '6. volume': '10268800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-11': {'1. open': '33.6000',
#    '2. high': '34.2800',
#    '3. low': '33.5900',
#    '4. close': '33.8800',
#    '5. adjusted close': '33.8514',
#    '6. volume': '19970500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-10': {'1. open': '33.1000',
#    '2. high': '33.5600',
#    '3. low': '33.0100',
#    '4. close': '33.4500',
#    '5. adjusted close': '33.4217',
#    '6. volume': '10893700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-09': {'1. open': '32.9900',
#    '2. high': '33.4400',
#    '3. low': '32.6300',
#    '4. close': '33.2100',
#    '5. adjusted close': '33.1819',
#    '6. volume': '12442900',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-08': {'1. open': '33.1200',
#    '2. high': '33.2700',
#    '3. low': '32.5600',
#    '4. close': '32.6900',
#    '5. adjusted close': '32.6624',
#    '6. volume': '14886100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-07': {'1. open': '33.2900',
#    '2. high': '33.6400',
#    '3. low': '32.7800',
#    '4. close': '32.8300',
#    '5. adjusted close': '32.8023',
#    '6. volume': '15574100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-04': {'1. open': '33.2300',
#    '2. high': '33.5000',
#    '3. low': '32.7700',
#    '4. close': '33.4500',
#    '5. adjusted close': '33.4217',
#    '6. volume': '25181500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-03': {'1. open': '33.2400',
#    '2. high': '33.6000',
#    '3. low': '32.8500',
#    '4. close': '33.2900',
#    '5. adjusted close': '33.2619',
#    '6. volume': '21920200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-02': {'1. open': '33.8500',
#    '2. high': '33.9400',
#    '3. low': '33.1200',
#    '4. close': '33.2800',
#    '5. adjusted close': '33.2519',
#    '6. volume': '23731200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-10-01': {'1. open': '35.2200',
#    '2. high': '35.3100',
#    '3. low': '34.2000',
#    '4. close': '34.2200',
#    '5. adjusted close': '34.1911',
#    '6. volume': '17096300',
#    '7. dividend amount': '0.0150',
#    '8. split coefficient': '1.0000'},
#   '2019-09-30': {'1. open': '35.5500',
#    '2. high': '35.7900',
#    '3. low': '35.0300',
#    '4. close': '35.0300',
#    '5. adjusted close': '34.9854',
#    '6. volume': '15985400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-27': {'1. open': '35.5900',
#    '2. high': '35.6400',
#    '3. low': '34.9700',
#    '4. close': '35.5300',
#    '5. adjusted close': '35.4848',
#    '6. volume': '16175900',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-26': {'1. open': '34.8800',
#    '2. high': '35.7000',
#    '3. low': '34.6000',
#    '4. close': '35.6800',
#    '5. adjusted close': '35.6346',
#    '6. volume': '18669400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-25': {'1. open': '34.1900',
#    '2. high': '34.9200',
#    '3. low': '34.0500',
#    '4. close': '34.6800',
#    '5. adjusted close': '34.6359',
#    '6. volume': '14271700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-24': {'1. open': '34.8200',
#    '2. high': '34.8900',
#    '3. low': '34.1100',
#    '4. close': '34.2800',
#    '5. adjusted close': '34.2364',
#    '6. volume': '10497600',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-23': {'1. open': '34.7000',
#    '2. high': '34.7200',
#    '3. low': '34.2000',
#    '4. close': '34.6400',
#    '5. adjusted close': '34.5959',
#    '6. volume': '13212100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-20': {'1. open': '34.8800',
#    '2. high': '35.1000',
#    '3. low': '34.6200',
#    '4. close': '34.7500',
#    '5. adjusted close': '34.7058',
#    '6. volume': '32900200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-19': {'1. open': '35.5400',
#    '2. high': '35.8300',
#    '3. low': '34.5200',
#    '4. close': '34.6600',
#    '5. adjusted close': '34.6159',
#    '6. volume': '17989000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-18': {'1. open': '35.3700',
#    '2. high': '35.6400',
#    '3. low': '34.8300',
#    '4. close': '35.2500',
#    '5. adjusted close': '35.2051',
#    '6. volume': '13316300',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-17': {'1. open': '34.9000',
#    '2. high': '35.4500',
#    '3. low': '34.8700',
#    '4. close': '35.3600',
#    '5. adjusted close': '35.3150',
#    '6. volume': '12250100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-16': {'1. open': '35.5300',
#    '2. high': '35.6200',
#    '3. low': '34.9100',
#    '4. close': '35.2300',
#    '5. adjusted close': '35.1852',
#    '6. volume': '20161300',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-13': {'1. open': '35.5100',
#    '2. high': '36.4100',
#    '3. low': '35.5100',
#    '4. close': '35.8700',
#    '5. adjusted close': '35.8243',
#    '6. volume': '25083000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-12': {'1. open': '35.5000',
#    '2. high': '35.6000',
#    '3. low': '35.1500',
#    '4. close': '35.3900',
#    '5. adjusted close': '35.3450',
#    '6. volume': '13645700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-11': {'1. open': '35.5100',
#    '2. high': '35.6800',
#    '3. low': '34.9900',
#    '4. close': '35.1700',
#    '5. adjusted close': '35.1252',
#    '6. volume': '16367700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-10': {'1. open': '36.1100',
#    '2. high': '36.2900',
#    '3. low': '35.0900',
#    '4. close': '35.3300',
#    '5. adjusted close': '35.2850',
#    '6. volume': '22274700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-09': {'1. open': '35.3700',
#    '2. high': '36.3000',
#    '3. low': '35.3600',
#    '4. close': '36.0300',
#    '5. adjusted close': '35.9841',
#    '6. volume': '34847900',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-06': {'1. open': '34.2500',
#    '2. high': '35.2300',
#    '3. low': '34.2500',
#    '4. close': '35.1700',
#    '5. adjusted close': '35.1252',
#    '6. volume': '21399400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-05': {'1. open': '33.4200',
#    '2. high': '34.6600',
#    '3. low': '33.3900',
#    '4. close': '34.0300',
#    '5. adjusted close': '33.9867',
#    '6. volume': '42036200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-04': {'1. open': '33.2800',
#    '2. high': '33.3100',
#    '3. low': '32.8100',
#    '4. close': '33.0900',
#    '5. adjusted close': '33.0479',
#    '6. volume': '15409600',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-03': {'1. open': '33.5100',
#    '2. high': '33.8100',
#    '3. low': '32.7700',
#    '4. close': '32.8600',
#    '5. adjusted close': '32.8182',
#    '6. volume': '19116300',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-09-02': {'1. open': '33.9000',
#    '2. high': '34.1900',
#    '3. low': '33.5000',
#    '4. close': '33.5000',
#    '5. adjusted close': '33.4574',
#    '6. volume': '8366100',
#    '7. dividend amount': '0.0150',
#    '8. split coefficient': '1.0000'},
#   '2019-08-30': {'1. open': '34.5300',
#    '2. high': '34.5600',
#    '3. low': '33.7800',
#    '4. close': '33.9400',
#    '5. adjusted close': '33.8818',
#    '6. volume': '25311700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-29': {'1. open': '34.0500',
#    '2. high': '34.4700',
#    '3. low': '33.5400',
#    '4. close': '34.0900',
#    '5. adjusted close': '34.0316',
#    '6. volume': '16919500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-28': {'1. open': '33.2200',
#    '2. high': '34.0900',
#    '3. low': '33.1600',
#    '4. close': '33.9100',
#    '5. adjusted close': '33.8519',
#    '6. volume': '14492900',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-27': {'1. open': '33.1500',
#    '2. high': '33.9300',
#    '3. low': '33.0800',
#    '4. close': '33.5300',
#    '5. adjusted close': '33.4725',
#    '6. volume': '28587300',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-26': {'1. open': '33.4100',
#    '2. high': '33.4300',
#    '3. low': '32.6900',
#    '4. close': '33.1400',
#    '5. adjusted close': '33.0832',
#    '6. volume': '17811500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-23': {'1. open': '33.0900',
#    '2. high': '33.9000',
#    '3. low': '32.9300',
#    '4. close': '33.1500',
#    '5. adjusted close': '33.0932',
#    '6. volume': '26285900',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-22': {'1. open': '34.1500',
#    '2. high': '34.3300',
#    '3. low': '33.5000',
#    '4. close': '33.5400',
#    '5. adjusted close': '33.4825',
#    '6. volume': '13552000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-21': {'1. open': '34.1900',
#    '2. high': '34.3400',
#    '3. low': '33.7600',
#    '4. close': '34.0800',
#    '5. adjusted close': '34.0216',
#    '6. volume': '19548800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-20': {'1. open': '34.3700',
#    '2. high': '34.4500',
#    '3. low': '33.5500',
#    '4. close': '33.8200',
#    '5. adjusted close': '33.7620',
#    '6. volume': '17302100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-19': {'1. open': '34.6500',
#    '2. high': '34.8700',
#    '3. low': '33.9100',
#    '4. close': '34.2000',
#    '5. adjusted close': '34.1414',
#    '6. volume': '22628600',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-16': {'1. open': '34.8000',
#    '2. high': '34.8600',
#    '3. low': '34.1300',
#    '4. close': '34.3500',
#    '5. adjusted close': '34.2911',
#    '6. volume': '14343000',
#    '7. dividend amount': '0.2393',
#    '8. split coefficient': '1.0000'},
#   '2019-08-15': {'1. open': '35.4800',
#    '2. high': '35.4800',
#    '3. low': '34.8100',
#    '4. close': '35.0000',
#    '5. adjusted close': '34.7011',
#    '6. volume': '19086500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-14': {'1. open': '35.4000',
#    '2. high': '35.5700',
#    '3. low': '35.0200',
#    '4. close': '35.1000',
#    '5. adjusted close': '34.8003',
#    '6. volume': '20769200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-13': {'1. open': '35.1800',
#    '2. high': '36.1200',
#    '3. low': '35.1200',
#    '4. close': '35.8900',
#    '5. adjusted close': '35.5835',
#    '6. volume': '13635000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-12': {'1. open': '36.0000',
#    '2. high': '36.0400',
#    '3. low': '35.1900',
#    '4. close': '35.2000',
#    '5. adjusted close': '34.8994',
#    '6. volume': '20246800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-09': {'1. open': '36.9900',
#    '2. high': '37.0000',
#    '3. low': '36.3500',
#    '4. close': '36.7200',
#    '5. adjusted close': '36.4064',
#    '6. volume': '11884800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-08': {'1. open': '37.0000',
#    '2. high': '37.3500',
#    '3. low': '36.6700',
#    '4. close': '37.0000',
#    '5. adjusted close': '36.6840',
#    '6. volume': '30196800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-07': {'1. open': '35.0700',
#    '2. high': '36.8000',
#    '3. low': '34.9600',
#    '4. close': '36.8000',
#    '5. adjusted close': '36.4857',
#    '6. volume': '32065800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-06': {'1. open': '34.9400',
#    '2. high': '35.4900',
#    '3. low': '34.8000',
#    '4. close': '35.4900',
#    '5. adjusted close': '35.1869',
#    '6. volume': '17746200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-05': {'1. open': '34.2000',
#    '2. high': '34.7200',
#    '3. low': '34.0400',
#    '4. close': '34.4500',
#    '5. adjusted close': '34.1558',
#    '6. volume': '21294600',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-02': {'1. open': '35.0000',
#    '2. high': '35.2000',
#    '3. low': '34.5800',
#    '4. close': '34.9300',
#    '5. adjusted close': '34.6317',
#    '6. volume': '27808000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-08-01': {'1. open': '35.2100',
#    '2. high': '36.1200',
#    '3. low': '34.8800',
#    '4. close': '34.8800',
#    '5. adjusted close': '34.5821',
#    '6. volume': '32801400',
#    '7. dividend amount': '0.0150',
#    '8. split coefficient': '1.0000'},
#   '2019-07-31': {'1. open': '35.7400',
#    '2. high': '35.7800',
#    '3. low': '34.7000',
#    '4. close': '34.8200',
#    '5. adjusted close': '34.5078',
#    '6. volume': '35542000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-30': {'1. open': '36.8000',
#    '2. high': '36.8000',
#    '3. low': '35.6600',
#    '4. close': '35.7700',
#    '5. adjusted close': '35.4493',
#    '6. volume': '44206600',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-29': {'1. open': '36.7600',
#    '2. high': '37.2700',
#    '3. low': '36.4500',
#    '4. close': '37.0000',
#    '5. adjusted close': '36.6682',
#    '6. volume': '20228700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-26': {'1. open': '36.4800',
#    '2. high': '37.0800',
#    '3. low': '36.0100',
#    '4. close': '36.8500',
#    '5. adjusted close': '36.5196',
#    '6. volume': '23826000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-25': {'1. open': '37.6500',
#    '2. high': '37.6500',
#    '3. low': '35.9800',
#    '4. close': '36.2000',
#    '5. adjusted close': '35.8754',
#    '6. volume': '22380700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-24': {'1. open': '37.5000',
#    '2. high': '37.7500',
#    '3. low': '37.1300',
#    '4. close': '37.3500',
#    '5. adjusted close': '37.0151',
#    '6. volume': '14689500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-23': {'1. open': '37.2500',
#    '2. high': '37.5500',
#    '3. low': '36.7300',
#    '4. close': '37.3800',
#    '5. adjusted close': '37.0448',
#    '6. volume': '21128500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-22': {'1. open': '36.6900',
#    '2. high': '37.2500',
#    '3. low': '36.6200',
#    '4. close': '37.0200',
#    '5. adjusted close': '36.6881',
#    '6. volume': '18663100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-19': {'1. open': '37.0800',
#    '2. high': '37.2800',
#    '3. low': '36.4000',
#    '4. close': '36.4000',
#    '5. adjusted close': '36.0736',
#    '6. volume': '17145500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-18': {'1. open': '36.4700',
#    '2. high': '37.3700',
#    '3. low': '36.4600',
#    '4. close': '37.3700',
#    '5. adjusted close': '37.0349',
#    '6. volume': '16209600',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-17': {'1. open': '36.5900',
#    '2. high': '36.9200',
#    '3. low': '36.3800',
#    '4. close': '36.4000',
#    '5. adjusted close': '36.0736',
#    '6. volume': '23122700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-16': {'1. open': '36.4000',
#    '2. high': '36.6500',
#    '3. low': '36.2100',
#    '4. close': '36.5000',
#    '5. adjusted close': '36.1727',
#    '6. volume': '17844700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-15': {'1. open': '36.6800',
#    '2. high': '36.7000',
#    '3. low': '36.1200',
#    '4. close': '36.3600',
#    '5. adjusted close': '36.0340',
#    '6. volume': '16642300',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-12': {'1. open': '37.4500',
#    '2. high': '37.4600',
#    '3. low': '36.4600',
#    '4. close': '36.4600',
#    '5. adjusted close': '36.1331',
#    '6. volume': '18723300',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-11': {'1. open': '36.9700',
#    '2. high': '37.1500',
#    '3. low': '36.5800',
#    '4. close': '37.1500',
#    '5. adjusted close': '36.8169',
#    '6. volume': '15289000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-10': {'1. open': '37.5300',
#    '2. high': '37.7200',
#    '3. low': '36.9500',
#    '4. close': '37.2000',
#    '5. adjusted close': '36.8664',
#    '6. volume': '22765400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-08': {'1. open': '37.4700',
#    '2. high': '37.5000',
#    '3. low': '37.0600',
#    '4. close': '37.3000',
#    '5. adjusted close': '36.9655',
#    '6. volume': '9918400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-05': {'1. open': '36.8400',
#    '2. high': '37.4500',
#    '3. low': '36.6700',
#    '4. close': '37.4000',
#    '5. adjusted close': '37.0646',
#    '6. volume': '14345800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-04': {'1. open': '36.7700',
#    '2. high': '37.5000',
#    '3. low': '36.7100',
#    '4. close': '36.9900',
#    '5. adjusted close': '36.6583',
#    '6. volume': '23138400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-03': {'1. open': '35.7000',
#    '2. high': '36.6500',
#    '3. low': '35.6300',
#    '4. close': '36.5700',
#    '5. adjusted close': '36.2421',
#    '6. volume': '17651400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-02': {'1. open': '36.0500',
#    '2. high': '36.3200',
#    '3. low': '35.7100',
#    '4. close': '35.9500',
#    '5. adjusted close': '35.6277',
#    '6. volume': '18830100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-07-01': {'1. open': '36.7700',
#    '2. high': '36.7700',
#    '3. low': '35.9400',
#    '4. close': '36.0800',
#    '5. adjusted close': '35.7565',
#    '6. volume': '15922800',
#    '7. dividend amount': '0.0150',
#    '8. split coefficient': '1.0000'},
#   '2019-06-28': {'1. open': '36.4500',
#    '2. high': '36.5900',
#    '3. low': '36.1400',
#    '4. close': '36.2600',
#    '5. adjusted close': '35.9200',
#    '6. volume': '17615100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-27': {'1. open': '36.2000',
#    '2. high': '36.4300',
#    '3. low': '35.7000',
#    '4. close': '36.2500',
#    '5. adjusted close': '35.9101',
#    '6. volume': '20630300',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-26': {'1. open': '35.8500',
#    '2. high': '36.5000',
#    '3. low': '35.7300',
#    '4. close': '36.5000',
#    '5. adjusted close': '36.1578',
#    '6. volume': '32869700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-25': {'1. open': '36.0000',
#    '2. high': '36.2300',
#    '3. low': '35.4800',
#    '4. close': '35.6500',
#    '5. adjusted close': '35.3157',
#    '6. volume': '23790600',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-24': {'1. open': '36.2400',
#    '2. high': '36.5000',
#    '3. low': '35.7900',
#    '4. close': '36.1000',
#    '5. adjusted close': '35.7615',
#    '6. volume': '22715800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-21': {'1. open': '35.5800',
#    '2. high': '36.1800',
#    '3. low': '35.5000',
#    '4. close': '36.1800',
#    '5. adjusted close': '35.8408',
#    '6. volume': '27455000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-19': {'1. open': '34.6400',
#    '2. high': '35.4900',
#    '3. low': '34.4700',
#    '4. close': '35.3800',
#    '5. adjusted close': '35.0483',
#    '6. volume': '23278900',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-18': {'1. open': '34.3500',
#    '2. high': '34.8300',
#    '3. low': '34.1800',
#    '4. close': '34.8300',
#    '5. adjusted close': '34.5034',
#    '6. volume': '22791000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-17': {'1. open': '33.9000',
#    '2. high': '34.3200',
#    '3. low': '33.8100',
#    '4. close': '33.9500',
#    '5. adjusted close': '33.6317',
#    '6. volume': '15638100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-14': {'1. open': '33.9000',
#    '2. high': '34.0700',
#    '3. low': '33.4800',
#    '4. close': '33.9900',
#    '5. adjusted close': '33.6713',
#    '6. volume': '18775100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-13': {'1. open': '34.5500',
#    '2. high': '34.5800',
#    '3. low': '33.7100',
#    '4. close': '33.9800',
#    '5. adjusted close': '33.6614',
#    '6. volume': '36877200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-12': {'1. open': '34.8000',
#    '2. high': '35.1200',
#    '3. low': '34.4700',
#    '4. close': '34.6000',
#    '5. adjusted close': '34.2756',
#    '6. volume': '17637000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-11': {'1. open': '34.8500',
#    '2. high': '34.9800',
#    '3. low': '34.2400',
#    '4. close': '34.8000',
#    '5. adjusted close': '34.4737',
#    '6. volume': '29136500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-10': {'1. open': '34.8500',
#    '2. high': '34.8700',
#    '3. low': '34.1100',
#    '4. close': '34.6300',
#    '5. adjusted close': '34.3053',
#    '6. volume': '18283400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-07': {'1. open': '34.7800',
#    '2. high': '35.2800',
#    '3. low': '34.6700',
#    '4. close': '35.0700',
#    '5. adjusted close': '34.7412',
#    '6. volume': '13355900',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-06': {'1. open': '34.6900',
#    '2. high': '34.8900',
#    '3. low': '34.3800',
#    '4. close': '34.7000',
#    '5. adjusted close': '34.3746',
#    '6. volume': '11449900',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-05': {'1. open': '35.0900',
#    '2. high': '35.1600',
#    '3. low': '34.2700',
#    '4. close': '34.3400',
#    '5. adjusted close': '34.0180',
#    '6. volume': '12193600',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-04': {'1. open': '35.2000',
#    '2. high': '35.3000',
#    '3. low': '34.7600',
#    '4. close': '35.0200',
#    '5. adjusted close': '34.6916',
#    '6. volume': '16554600',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-06-03': {'1. open': '35.2000',
#    '2. high': '35.3200',
#    '3. low': '34.7300',
#    '4. close': '35.0800',
#    '5. adjusted close': '34.7511',
#    '6. volume': '18939200',
#    '7. dividend amount': '0.0150',
#    '8. split coefficient': '1.0000'},
#   '2019-05-31': {'1. open': '34.8900',
#    '2. high': '35.4000',
#    '3. low': '34.7500',
#    '4. close': '35.0000',
#    '5. adjusted close': '34.6570',
#    '6. volume': '18216700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-30': {'1. open': '34.8100',
#    '2. high': '35.2200',
#    '3. low': '34.6800',
#    '4. close': '35.0800',
#    '5. adjusted close': '34.7362',
#    '6. volume': '15947600',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-29': {'1. open': '33.8500',
#    '2. high': '34.8900',
#    '3. low': '33.8500',
#    '4. close': '34.7200',
#    '5. adjusted close': '34.3797',
#    '6. volume': '28132700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-28': {'1. open': '33.2800',
#    '2. high': '34.0800',
#    '3. low': '33.1200',
#    '4. close': '34.0800',
#    '5. adjusted close': '33.7460',
#    '6. volume': '32564800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-27': {'1. open': '33.3300',
#    '2. high': '33.5800',
#    '3. low': '33.0300',
#    '4. close': '33.1500',
#    '5. adjusted close': '32.8251',
#    '6. volume': '10607500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-24': {'1. open': '33.8000',
#    '2. high': '33.8500',
#    '3. low': '33.0100',
#    '4. close': '33.0300',
#    '5. adjusted close': '32.7063',
#    '6. volume': '11538100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-23': {'1. open': '33.3900',
#    '2. high': '33.7200',
#    '3. low': '33.1300',
#    '4. close': '33.5300',
#    '5. adjusted close': '33.2014',
#    '6. volume': '15793700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-22': {'1. open': '33.7000',
#    '2. high': '33.8000',
#    '3. low': '32.9700',
#    '4. close': '33.6000',
#    '5. adjusted close': '33.2707',
#    '6. volume': '13175500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-21': {'1. open': '32.4000',
#    '2. high': '33.5900',
#    '3. low': '32.3600',
#    '4. close': '33.5700',
#    '5. adjusted close': '33.2410',
#    '6. volume': '23455000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-20': {'1. open': '31.7000',
#    '2. high': '32.3800',
#    '3. low': '31.3900',
#    '4. close': '32.3200',
#    '5. adjusted close': '32.0032',
#    '6. volume': '24166700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-17': {'1. open': '31.3700',
#    '2. high': '32.0000',
#    '3. low': '31.1100',
#    '4. close': '31.5000',
#    '5. adjusted close': '31.1913',
#    '6. volume': '23815600',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-16': {'1. open': '31.5000',
#    '2. high': '31.6700',
#    '3. low': '31.1600',
#    '4. close': '31.4400',
#    '5. adjusted close': '31.1319',
#    '6. volume': '18017400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-15': {'1. open': '31.5100',
#    '2. high': '31.8500',
#    '3. low': '31.1400',
#    '4. close': '31.8500',
#    '5. adjusted close': '31.5378',
#    '6. volume': '21154800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-14': {'1. open': '32.0700',
#    '2. high': '32.1800',
#    '3. low': '31.6300',
#    '4. close': '31.7500',
#    '5. adjusted close': '31.4388',
#    '6. volume': '13339700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-13': {'1. open': '31.7200',
#    '2. high': '32.0500',
#    '3. low': '31.6600',
#    '4. close': '31.9000',
#    '5. adjusted close': '31.5873',
#    '6. volume': '19063500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-10': {'1. open': '32.4900',
#    '2. high': '32.8000',
#    '3. low': '32.0300',
#    '4. close': '32.4100',
#    '5. adjusted close': '32.0923',
#    '6. volume': '14490800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-09': {'1. open': '32.5700',
#    '2. high': '32.8700',
#    '3. low': '32.2400',
#    '4. close': '32.5600',
#    '5. adjusted close': '32.2409',
#    '6. volume': '21662400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-08': {'1. open': '32.7400',
#    '2. high': '33.3800',
#    '3. low': '32.7400',
#    '4. close': '32.9700',
#    '5. adjusted close': '32.6469',
#    '6. volume': '18049500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-07': {'1. open': '32.7000',
#    '2. high': '32.7200',
#    '3. low': '31.9500',
#    '4. close': '32.6000',
#    '5. adjusted close': '32.2805',
#    '6. volume': '29106700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-06': {'1. open': '33.3400',
#    '2. high': '33.4900',
#    '3. low': '32.9300',
#    '4. close': '32.9700',
#    '5. adjusted close': '32.6469',
#    '6. volume': '14639700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-03': {'1. open': '34.2000',
#    '2. high': '34.2800',
#    '3. low': '33.6400',
#    '4. close': '33.7100',
#    '5. adjusted close': '33.3796',
#    '6. volume': '31030200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-05-02': {'1. open': '33.6700',
#    '2. high': '34.2200',
#    '3. low': '33.5900',
#    '4. close': '34.0400',
#    '5. adjusted close': '33.7064',
#    '6. volume': '14629500',
#    '7. dividend amount': '0.0150',
#    '8. split coefficient': '1.0000'},
#   '2019-04-30': {'1. open': '33.6900',
#    '2. high': '34.0300',
#    '3. low': '33.4300',
#    '4. close': '33.8300',
#    '5. adjusted close': '33.4836',
#    '6. volume': '13501100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-29': {'1. open': '33.9500',
#    '2. high': '34.1100',
#    '3. low': '33.3900',
#    '4. close': '33.5300',
#    '5. adjusted close': '33.1866',
#    '6. volume': '11055200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-26': {'1. open': '33.8100',
#    '2. high': '33.9200',
#    '3. low': '33.4100',
#    '4. close': '33.8000',
#    '5. adjusted close': '33.4539',
#    '6. volume': '10071700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-25': {'1. open': '33.0200',
#    '2. high': '33.8000',
#    '3. low': '32.6400',
#    '4. close': '33.7200',
#    '5. adjusted close': '33.3747',
#    '6. volume': '19588900',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-24': {'1. open': '33.1800',
#    '2. high': '33.2400',
#    '3. low': '32.6800',
#    '4. close': '33.2100',
#    '5. adjusted close': '32.8699',
#    '6. volume': '14647000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-23': {'1. open': '33.0000',
#    '2. high': '33.4500',
#    '3. low': '33.0000',
#    '4. close': '33.1600',
#    '5. adjusted close': '32.8204',
#    '6. volume': '13401400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-22': {'1. open': '32.7700',
#    '2. high': '33.1500',
#    '3. low': '32.3900',
#    '4. close': '32.7400',
#    '5. adjusted close': '32.4047',
#    '6. volume': '10063200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-18': {'1. open': '32.5200',
#    '2. high': '33.2000',
#    '3. low': '32.1200',
#    '4. close': '32.8300',
#    '5. adjusted close': '32.4938',
#    '6. volume': '17515300',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-17': {'1. open': '33.0000',
#    '2. high': '33.2000',
#    '3. low': '32.0000',
#    '4. close': '32.3900',
#    '5. adjusted close': '32.0583',
#    '6. volume': '35979200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-16': {'1. open': '32.7200',
#    '2. high': '33.4600',
#    '3. low': '32.7200',
#    '4. close': '32.9000',
#    '5. adjusted close': '32.5631',
#    '6. volume': '16992700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-15': {'1. open': '33.2400',
#    '2. high': '33.3300',
#    '3. low': '32.6400',
#    '4. close': '32.9300',
#    '5. adjusted close': '32.5928',
#    '6. volume': '16527700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-12': {'1. open': '33.0000',
#    '2. high': '33.8200',
#    '3. low': '32.6500',
#    '4. close': '32.9500',
#    '5. adjusted close': '32.6126',
#    '6. volume': '29457500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-11': {'1. open': '33.8200',
#    '2. high': '34.0400',
#    '3. low': '33.1100',
#    '4. close': '33.3000',
#    '5. adjusted close': '32.9590',
#    '6. volume': '12091400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-10': {'1. open': '34.4000',
#    '2. high': '34.4400',
#    '3. low': '33.8100',
#    '4. close': '34.0900',
#    '5. adjusted close': '33.7409',
#    '6. volume': '26315900',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-09': {'1. open': '34.2000',
#    '2. high': '34.2200',
#    '3. low': '33.6100',
#    '4. close': '34.1500',
#    '5. adjusted close': '33.8003',
#    '6. volume': '13385100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-08': {'1. open': '34.6000',
#    '2. high': '34.6700',
#    '3. low': '34.1500',
#    '4. close': '34.3400',
#    '5. adjusted close': '33.9884',
#    '6. volume': '9190600',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-05': {'1. open': '34.0000',
#    '2. high': '34.6700',
#    '3. low': '33.8000',
#    '4. close': '34.5500',
#    '5. adjusted close': '34.1962',
#    '6. volume': '16192100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-04': {'1. open': '33.6900',
#    '2. high': '34.0900',
#    '3. low': '33.2500',
#    '4. close': '33.8200',
#    '5. adjusted close': '33.4737',
#    '6. volume': '18053600',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-03': {'1. open': '34.0400',
#    '2. high': '34.1900',
#    '3. low': '33.1700',
#    '4. close': '33.3200',
#    '5. adjusted close': '32.9788',
#    '6. volume': '19468200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-02': {'1. open': '34.2500',
#    '2. high': '34.3300',
#    '3. low': '33.5300',
#    '4. close': '33.6200',
#    '5. adjusted close': '33.2757',
#    '6. volume': '16358100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-04-01': {'1. open': '34.7000',
#    '2. high': '34.8000',
#    '3. low': '34.0000',
#    '4. close': '34.1600',
#    '5. adjusted close': '33.8102',
#    '6. volume': '17229600',
#    '7. dividend amount': '0.0150',
#    '8. split coefficient': '1.0000'},
#   '2019-03-29': {'1. open': '34.5200',
#    '2. high': '34.5500',
#    '3. low': '33.9200',
#    '4. close': '34.4300',
#    '5. adjusted close': '34.0626',
#    '6. volume': '19700400',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-28': {'1. open': '32.9000',
#    '2. high': '34.3400',
#    '3. low': '32.6500',
#    '4. close': '34.1000',
#    '5. adjusted close': '33.7361',
#    '6. volume': '31144800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-27': {'1. open': '33.4300',
#    '2. high': '33.6400',
#    '3. low': '32.7900',
#    '4. close': '32.8000',
#    '5. adjusted close': '32.4500',
#    '6. volume': '28321300',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-26': {'1. open': '34.0000',
#    '2. high': '34.1100',
#    '3. low': '33.5000',
#    '4. close': '33.9500',
#    '5. adjusted close': '33.5877',
#    '6. volume': '16071700',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-25': {'1. open': '33.4900',
#    '2. high': '34.1200',
#    '3. low': '33.3000',
#    '4. close': '33.6000',
#    '5. adjusted close': '33.2414',
#    '6. volume': '19909900',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-22': {'1. open': '34.0500',
#    '2. high': '34.1200',
#    '3. low': '33.3600',
#    '4. close': '33.5500',
#    '5. adjusted close': '33.1920',
#    '6. volume': '30631500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-21': {'1. open': '35.3100',
#    '2. high': '35.4100',
#    '3. low': '34.1000',
#    '4. close': '34.5700',
#    '5. adjusted close': '34.2011',
#    '6. volume': '31558000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-20': {'1. open': '36.0600',
#    '2. high': '36.2200',
#    '3. low': '35.1900',
#    '4. close': '35.1900',
#    '5. adjusted close': '34.8145',
#    '6. volume': '26182500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-19': {'1. open': '37.0000',
#    '2. high': '37.0000',
#    '3. low': '36.0000',
#    '4. close': '36.0000',
#    '5. adjusted close': '35.6158',
#    '6. volume': '35023800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-18': {'1. open': '36.8600',
#    '2. high': '37.0600',
#    '3. low': '36.7400',
#    '4. close': '36.8600',
#    '5. adjusted close': '36.4667',
#    '6. volume': '11303100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-15': {'1. open': '36.7300',
#    '2. high': '37.1700',
#    '3. low': '36.4800',
#    '4. close': '36.8000',
#    '5. adjusted close': '36.4073',
#    '6. volume': '19106000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-14': {'1. open': '37.4000',
#    '2. high': '37.4000',
#    '3. low': '36.4400',
#    '4. close': '36.8100',
#    '5. adjusted close': '36.4172',
#    '6. volume': '17809100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-13': {'1. open': '36.8200',
#    '2. high': '37.6700',
#    '3. low': '36.7000',
#    '4. close': '37.4000',
#    '5. adjusted close': '37.0009',
#    '6. volume': '22202800',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-12': {'1. open': '36.9200',
#    '2. high': '37.0000',
#    '3. low': '36.5900',
#    '4. close': '37.0000',
#    '5. adjusted close': '36.6052',
#    '6. volume': '13109300',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-11': {'1. open': '35.8500',
#    '2. high': '37.0200',
#    '3. low': '35.8300',
#    '4. close': '36.9200',
#    '5. adjusted close': '36.5260',
#    '6. volume': '19995500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-08': {'1. open': '35.1200',
#    '2. high': '35.8900',
#    '3. low': '34.8500',
#    '4. close': '35.7500',
#    '5. adjusted close': '35.3685',
#    '6. volume': '13565000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-07': {'1. open': '34.8000',
#    '2. high': '35.5400',
#    '3. low': '34.6700',
#    '4. close': '35.3300',
#    '5. adjusted close': '34.9530',
#    '6. volume': '18963500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2019-03-01': {'1. open': '35.4900',
#    '2. high': '35.5900',
#    '3. low': '34.8400',
#    '4. close': '34.8400',
#    '5. adjusted close': '34.4682',
#    '6. volume': '16152300',
#    '7. dividend amount': '0.0150',
#    '8. split coefficient': '1.0000'},
#   '2019-02-28': {'1. open': '35.9300',
#    '2. high': '36.0200',
#    '3. low': '35.1700',
#    '4. close': '35.2300',
#    '5. adjusted close': '34.8392',
#    '6. volume': '18012500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
# ...
#    '2. high': '19.0303',
#    '3. low': '18.3636',
#    '4. close': '18.9151',
#    '5. adjusted close': '16.2821',
#    '6. volume': '30214470',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-03-04': {'1. open': '18.1152',
#    '2. high': '19.6606',
#    '3. low': '18.1152',
#    '4. close': '19.0000',
#    '5. adjusted close': '16.3551',
#    '6. volume': '82980480',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-03-03': {'1. open': '16.6667',
#    '2. high': '18.1636',
#    '3. low': '16.6606',
#    '4. close': '18.1152',
#    '5. adjusted close': '15.5935',
#    '6. volume': '69189780',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-03-02': {'1. open': '16.1212',
#    '2. high': '16.5394',
#    '3. low': '15.8970',
#    '4. close': '16.4848',
#    '5. adjusted close': '14.1901',
#    '6. volume': '40292340',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-03-01': {'1. open': '15.5394',
#    '2. high': '16.1091',
#    '3. low': '15.4545',
#    '4. close': '16.1091',
#    '5. adjusted close': '13.8667',
#    '6. volume': '36920235',
#    '7. dividend amount': '0.0150',
#    '8. split coefficient': '1.0000'},
#   '2016-02-29': {'1. open': '15.2121',
#    '2. high': '15.4485',
#    '3. low': '15.0303',
#    '4. close': '15.3939',
#    '5. adjusted close': '13.2381',
#    '6. volume': '34760550',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-26': {'1. open': '15.0727',
#    '2. high': '15.2606',
#    '3. low': '14.8606',
#    '4. close': '14.9697',
#    '5. adjusted close': '12.8733',
#    '6. volume': '15535410',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-25': {'1. open': '14.8121',
#    '2. high': '15.2364',
#    '3. low': '14.7091',
#    '4. close': '14.9697',
#    '5. adjusted close': '12.8733',
#    '6. volume': '17569035',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-24': {'1. open': '14.8727',
#    '2. high': '15.0606',
#    '3. low': '14.6364',
#    '4. close': '14.9576',
#    '5. adjusted close': '12.8629',
#    '6. volume': '17499735',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-23': {'1. open': '15.1697',
#    '2. high': '15.4545',
#    '3. low': '14.9818',
#    '4. close': '15.0849',
#    '5. adjusted close': '12.9724',
#    '6. volume': '20040570',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-22': {'1. open': '15.1212',
#    '2. high': '15.3939',
#    '3. low': '15.0000',
#    '4. close': '15.3030',
#    '5. adjusted close': '13.1599',
#    '6. volume': '42384375',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-19': {'1. open': '14.4667',
#    '2. high': '14.8061',
#    '3. low': '14.4000',
#    '4. close': '14.7091',
#    '5. adjusted close': '12.6492',
#    '6. volume': '20481780',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-18': {'1. open': '15.0788',
#    '2. high': '15.0909',
#    '3. low': '14.7576',
#    '4. close': '14.9333',
#    '5. adjusted close': '12.8420',
#    '6. volume': '30770190',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-17': {'1. open': '15.2727',
#    '2. high': '15.6727',
#    '3. low': '14.9394',
#    '4. close': '15.2424',
#    '5. adjusted close': '13.1078',
#    '6. volume': '41933430',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-16': {'1. open': '14.7576',
#    '2. high': '15.3273',
#    '3. low': '14.6424',
#    '4. close': '15.0788',
#    '5. adjusted close': '12.9671',
#    '6. volume': '31493550',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-15': {'1. open': '15.0242',
#    '2. high': '15.0546',
#    '3. low': '14.7212',
#    '4. close': '14.7212',
#    '5. adjusted close': '12.6596',
#    '6. volume': '10821195',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-12': {'1. open': '14.7636',
#    '2. high': '14.8000',
#    '3. low': '14.4970',
#    '4. close': '14.7697',
#    '5. adjusted close': '12.7013',
#    '6. volume': '16816305',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-11': {'1. open': '14.8061',
#    '2. high': '14.8909',
#    '3. low': '14.4909',
#    '4. close': '14.6545',
#    '5. adjusted close': '12.6023',
#    '6. volume': '17631735',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-10': {'1. open': '14.8364',
#    '2. high': '15.1212',
#    '3. low': '14.7576',
#    '4. close': '15.1030',
#    '5. adjusted close': '12.9879',
#    '6. volume': '12062655',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-05': {'1. open': '14.8485',
#    '2. high': '15.2424',
#    '3. low': '14.7394',
#    '4. close': '15.0303',
#    '5. adjusted close': '12.9254',
#    '6. volume': '23766930',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-04': {'1. open': '14.9091',
#    '2. high': '15.3091',
#    '3. low': '14.4303',
#    '4. close': '14.8848',
#    '5. adjusted close': '12.8003',
#    '6. volume': '37742760',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-03': {'1. open': '14.4182',
#    '2. high': '14.7515',
#    '3. low': '14.3939',
#    '4. close': '14.6727',
#    '5. adjusted close': '12.6179',
#    '6. volume': '38135460',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-02': {'1. open': '14.8242',
#    '2. high': '14.8485',
#    '3. low': '14.0909',
#    '4. close': '14.3273',
#    '5. adjusted close': '12.3209',
#    '6. volume': '74752260',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-02-01': {'1. open': '14.9758',
#    '2. high': '15.4364',
#    '3. low': '14.8182',
#    '4. close': '15.4364',
#    '5. adjusted close': '13.2747',
#    '6. volume': '19258800',
#    '7. dividend amount': '0.0150',
#    '8. split coefficient': '1.0000'},
#   '2016-01-29': {'1. open': '14.6061',
#    '2. high': '15.1212',
#    '3. low': '14.5455',
#    '4. close': '15.1212',
#    '5. adjusted close': '12.9907',
#    '6. volume': '30569220',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-28': {'1. open': '14.5091',
#    '2. high': '14.5879',
#    '3. low': '14.3030',
#    '4. close': '14.4485',
#    '5. adjusted close': '12.4128',
#    '6. volume': '16516005',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-27': {'1. open': '14.2242',
#    '2. high': '14.5576',
#    '3. low': '14.0788',
#    '4. close': '14.3515',
#    '5. adjusted close': '12.3294',
#    '6. volume': '23269455',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-26': {'1. open': '13.9697',
#    '2. high': '14.2970',
#    '3. low': '13.8909',
#    '4. close': '14.2970',
#    '5. adjusted close': '12.2826',
#    '6. volume': '18401130',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-22': {'1. open': '14.1515',
#    '2. high': '14.3333',
#    '3. low': '14.0667',
#    '4. close': '14.1454',
#    '5. adjusted close': '12.1524',
#    '6. volume': '15794460',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-21': {'1. open': '13.9394',
#    '2. high': '14.2242',
#    '3. low': '13.9091',
#    '4. close': '14.0121',
#    '5. adjusted close': '12.0379',
#    '6. volume': '29577240',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-20': {'1. open': '13.9394',
#    '2. high': '14.0727',
#    '3. low': '13.8242',
#    '4. close': '13.9818',
#    '5. adjusted close': '12.0118',
#    '6. volume': '36861825',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-19': {'1. open': '14.5636',
#    '2. high': '14.6485',
#    '3. low': '14.0849',
#    '4. close': '14.1818',
#    '5. adjusted close': '12.1837',
#    '6. volume': '16685460',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-18': {'1. open': '14.5455',
#    '2. high': '14.5879',
#    '3. low': '14.3273',
#    '4. close': '14.3273',
#    '5. adjusted close': '12.3086',
#    '6. volume': '10937685',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-15': {'1. open': '14.6061',
#    '2. high': '14.6667',
#    '3. low': '14.3697',
#    '4. close': '14.4970',
#    '5. adjusted close': '12.4544',
#    '6. volume': '30337560',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-14': {'1. open': '14.7273',
#    '2. high': '14.8970',
#    '3. low': '14.3394',
#    '4. close': '14.8848',
#    '5. adjusted close': '12.7876',
#    '6. volume': '23442375',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-13': {'1. open': '15.0667',
#    '2. high': '15.1515',
#    '3. low': '14.5818',
#    '4. close': '14.6727',
#    '5. adjusted close': '12.6054',
#    '6. volume': '19543260',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-12': {'1. open': '15.0303',
#    '2. high': '15.1758',
#    '3. low': '14.7939',
#    '4. close': '14.9030',
#    '5. adjusted close': '12.8032',
#    '6. volume': '18183000',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-11': {'1. open': '15.0970',
#    '2. high': '15.1697',
#    '3. low': '14.8061',
#    '4. close': '14.8364',
#    '5. adjusted close': '12.7460',
#    '6. volume': '19219695',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-08': {'1. open': '15.1212',
#    '2. high': '15.3030',
#    '3. low': '15.0121',
#    '4. close': '15.0121',
#    '5. adjusted close': '12.8970',
#    '6. volume': '18087465',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-07': {'1. open': '15.0909',
#    '2. high': '15.3273',
#    '3. low': '15.0061',
#    '4. close': '15.0061',
#    '5. adjusted close': '12.8918',
#    '6. volume': '28766430',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-06': {'1. open': '15.1515',
#    '2. high': '15.6545',
#    '3. low': '15.0303',
#    '4. close': '15.2970',
#    '5. adjusted close': '13.1417',
#    '6. volume': '33520575',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-05': {'1. open': '15.3939',
#    '2. high': '15.6242',
#    '3. low': '15.2000',
#    '4. close': '15.3576',
#    '5. adjusted close': '13.1938',
#    '6. volume': '21093105',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2016-01-04': {'1. open': '15.7091',
#    '2. high': '15.8121',
#    '3. low': '15.2303',
#    '4. close': '15.2303',
#    '5. adjusted close': '13.0844',
#    '6. volume': '38071770',
#    '7. dividend amount': '0.0150',
#    '8. split coefficient': '1.0000'},
#   '2015-12-30': {'1. open': '16.0788',
#    '2. high': '16.0788',
#    '3. low': '15.8000',
#    '4. close': '15.9576',
#    '5. adjusted close': '13.6964',
#    '6. volume': '21126765',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-29': {'1. open': '16.1212',
#    '2. high': '16.1576',
#    '3. low': '15.9273',
#    '4. close': '16.0121',
#    '5. adjusted close': '13.7431',
#    '6. volume': '12012165',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-28': {'1. open': '16.0909',
#    '2. high': '16.1939',
#    '3. low': '16.0000',
#    '4. close': '16.0000',
#    '5. adjusted close': '13.7328',
#    '6. volume': '28203780',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-23': {'1. open': '16.4182',
#    '2. high': '16.4182',
#    '3. low': '15.9454',
#    '4. close': '16.0606',
#    '5. adjusted close': '13.7848',
#    '6. volume': '19590450',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-22': {'1. open': '16.2121',
#    '2. high': '16.3394',
#    '3. low': '15.9394',
#    '4. close': '16.1212',
#    '5. adjusted close': '13.8368',
#    '6. volume': '28014855',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-21': {'1. open': '16.4242',
#    '2. high': '16.4848',
#    '3. low': '15.9394',
#    '4. close': '16.0182',
#    '5. adjusted close': '13.7484',
#    '6. volume': '32174175',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-18': {'1. open': '16.8909',
#    '2. high': '16.9515',
#    '3. low': '16.3212',
#    '4. close': '16.3212',
#    '5. adjusted close': '14.0084',
#    '6. volume': '56025750',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-17': {'1. open': '17.3939',
#    '2. high': '17.6182',
#    '3. low': '17.2485',
#    '4. close': '17.3273',
#    '5. adjusted close': '14.8720',
#    '6. volume': '20040075',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-16': {'1. open': '17.0000',
#    '2. high': '17.1333',
#    '3. low': '16.6061',
#    '4. close': '17.0364',
#    '5. adjusted close': '14.6223',
#    '6. volume': '29401680',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-15': {'1. open': '17.0970',
#    '2. high': '17.4606',
#    '3. low': '17.0970',
#    '4. close': '17.1515',
#    '5. adjusted close': '14.7211',
#    '6. volume': '33409200',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-14': {'1. open': '17.2848',
#    '2. high': '17.3212',
#    '3. low': '16.9151',
#    '4. close': '17.0424',
#    '5. adjusted close': '14.6274',
#    '6. volume': '19957575',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-11': {'1. open': '17.2788',
#    '2. high': '17.6061',
#    '3. low': '17.1939',
#    '4. close': '17.4545',
#    '5. adjusted close': '14.9811',
#    '6. volume': '22458810',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-10': {'1. open': '17.5030',
#    '2. high': '17.6303',
#    '3. low': '17.3394',
#    '4. close': '17.4545',
#    '5. adjusted close': '14.9811',
#    '6. volume': '23940180',
#    '7. dividend amount': '0.2090',
#    '8. split coefficient': '1.0000'},
#   '2015-12-09': {'1. open': '17.0000',
#    '2. high': '17.7152',
#    '3. low': '16.9818',
#    '4. close': '17.6667',
#    '5. adjusted close': '14.9839',
#    '6. volume': '47833500',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-08': {'1. open': '16.9454',
#    '2. high': '16.9454',
#    '3. low': '16.5515',
#    '4. close': '16.7576',
#    '5. adjusted close': '14.2128',
#    '6. volume': '32438010',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-07': {'1. open': '17.2788',
#    '2. high': '17.3939',
#    '3. low': '16.8788',
#    '4. close': '16.9515',
#    '5. adjusted close': '14.3773',
#    '6. volume': '26038485',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-04': {'1. open': '17.3151',
#    '2. high': '17.3879',
#    '3. low': '16.7879',
#    '4. close': '17.0788',
#    '5. adjusted close': '14.4853',
#    '6. volume': '29007165',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-03': {'1. open': '17.1515',
#    '2. high': '17.8303',
#    '3. low': '17.0303',
#    '4. close': '17.4667',
#    '5. adjusted close': '14.8143',
#    '6. volume': '53560980',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-02': {'1. open': '16.8909',
#    '2. high': '17.0000',
#    '3. low': '16.3394',
#    '4. close': '16.4242',
#    '5. adjusted close': '13.9301',
#    '6. volume': '34838100',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   '2015-12-01': {'1. open': '16.8788',
#    '2. high': '17.0242',
#    '3. low': '16.6182',
#    '4. close': '16.9636',
#    '5. adjusted close': '14.3876',
#    '6. volume': '21762015',
#    '7. dividend amount': '0.0150',
#    '8. split coefficient': '1.0000'},
#   '2015-11-30': {'1. open': '16.6061',
#    '2. high': '17.0000',
#    '3. low': '16.4303',
#    '4. close': '16.8424',
#    '5. adjusted close': '14.2720',
#    '6. volume': '45753510',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0000'},
#   ...}}

# %%
info['Meta Data']
# Out:
# {'1. Information': 'Daily Time Series with Splits and Dividend Events',
#  '2. Symbol': 'ITUB4.SA',
#  '3. Last Refreshed': '2019-12-04',
#  '4. Output Size': 'Full size',
#  '5. Time Zone': 'US/Eastern'}

# %%
info['Time Series (Daily)']
# Out:
# {'2019-12-04': {'1. open': '35.3900',
#   '2. high': '36.5700',
#   '3. low': '35.3000',
#   '4. close': '36.4200',
#   '5. adjusted close': '36.4200',
#   '6. volume': '25791900',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-12-03': {'1. open': '35.5900',
#   '2. high': '35.7100',
#   '3. low': '34.9100',
#   '4. close': '35.2900',
#   '5. adjusted close': '35.2900',
#   '6. volume': '15999200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-12-02': {'1. open': '34.9200',
#   '2. high': '35.5200',
#   '3. low': '34.8400',
#   '4. close': '35.2800',
#   '5. adjusted close': '35.2800',
#   '6. volume': '16447900',
#   '7. dividend amount': '0.0150',
#   '8. split coefficient': '1.0000'},
#  '2019-11-29': {'1. open': '34.6700',
#   '2. high': '34.8300',
#   '3. low': '34.3000',
#   '4. close': '34.8000',
#   '5. adjusted close': '34.7850',
#   '6. volume': '16530900',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-28': {'1. open': '34.4500',
#   '2. high': '34.7000',
#   '3. low': '34.0200',
#   '4. close': '34.6000',
#   '5. adjusted close': '34.5851',
#   '6. volume': '15850200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-27': {'1. open': '34.7000',
#   '2. high': '34.9300',
#   '3. low': '34.2600',
#   '4. close': '34.7000',
#   '5. adjusted close': '34.6850',
#   '6. volume': '19366600',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-26': {'1. open': '35.0000',
#   '2. high': '35.0900',
#   '3. low': '34.3500',
#   '4. close': '34.5000',
#   '5. adjusted close': '34.4851',
#   '6. volume': '26176400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-25': {'1. open': '35.7900',
#   '2. high': '35.9000',
#   '3. low': '35.0100',
#   '4. close': '35.2200',
#   '5. adjusted close': '35.2048',
#   '6. volume': '15202500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-22': {'1. open': '35.2600',
#   '2. high': '35.8300',
#   '3. low': '35.2100',
#   '4. close': '35.7300',
#   '5. adjusted close': '35.7146',
#   '6. volume': '16433000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-21': {'1. open': '35.1300',
#   '2. high': '35.5000',
#   '3. low': '35.0300',
#   '4. close': '35.4900',
#   '5. adjusted close': '35.4747',
#   '6. volume': '26063800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-19': {'1. open': '35.5000',
#   '2. high': '35.6000',
#   '3. low': '34.8500',
#   '4. close': '35.1300',
#   '5. adjusted close': '35.1149',
#   '6. volume': '17887600',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-18': {'1. open': '36.0000',
#   '2. high': '36.2000',
#   '3. low': '35.4800',
#   '4. close': '35.5200',
#   '5. adjusted close': '35.5047',
#   '6. volume': '13345400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-14': {'1. open': '35.5000',
#   '2. high': '35.7900',
#   '3. low': '35.1600',
#   '4. close': '35.6800',
#   '5. adjusted close': '35.6646',
#   '6. volume': '14012300',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-13': {'1. open': '35.6700',
#   '2. high': '35.8400',
#   '3. low': '35.1800',
#   '4. close': '35.4500',
#   '5. adjusted close': '35.4347',
#   '6. volume': '17688000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-12': {'1. open': '36.0200',
#   '2. high': '36.2900',
#   '3. low': '35.4300',
#   '4. close': '35.8100',
#   '5. adjusted close': '35.7946',
#   '6. volume': '19644000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-11': {'1. open': '36.2000',
#   '2. high': '36.8000',
#   '3. low': '35.9000',
#   '4. close': '36.4300',
#   '5. adjusted close': '36.4143',
#   '6. volume': '17480000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-08': {'1. open': '36.3600',
#   '2. high': '36.7800',
#   '3. low': '36.0200',
#   '4. close': '36.2700',
#   '5. adjusted close': '36.2544',
#   '6. volume': '15088000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-07': {'1. open': '36.7800',
#   '2. high': '36.9500',
#   '3. low': '36.5700',
#   '4. close': '36.8200',
#   '5. adjusted close': '36.8041',
#   '6. volume': '15689500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-06': {'1. open': '37.1000',
#   '2. high': '37.3600',
#   '3. low': '36.5700',
#   '4. close': '36.6000',
#   '5. adjusted close': '36.5842',
#   '6. volume': '19030900',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-05': {'1. open': '37.6400',
#   '2. high': '37.9900',
#   '3. low': '36.8000',
#   '4. close': '37.1000',
#   '5. adjusted close': '37.0840',
#   '6. volume': '46982800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-04': {'1. open': '36.4500',
#   '2. high': '36.7500',
#   '3. low': '36.2400',
#   '4. close': '36.4700',
#   '5. adjusted close': '36.4543',
#   '6. volume': '10065400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-11-01': {'1. open': '36.6600',
#   '2. high': '36.9100',
#   '3. low': '35.9100',
#   '4. close': '36.3500',
#   '5. adjusted close': '36.3343',
#   '6. volume': '18958400',
#   '7. dividend amount': '0.0150',
#   '8. split coefficient': '1.0000'},
#  '2019-10-31': {'1. open': '36.3000',
#   '2. high': '36.6700',
#   '3. low': '35.6800',
#   '4. close': '36.2300',
#   '5. adjusted close': '36.1994',
#   '6. volume': '26038300',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-30': {'1. open': '36.4700',
#   '2. high': '37.0000',
#   '3. low': '35.9100',
#   '4. close': '36.8700',
#   '5. adjusted close': '36.8388',
#   '6. volume': '23575800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-29': {'1. open': '37.0900',
#   '2. high': '37.2300',
#   '3. low': '36.5700',
#   '4. close': '36.6400',
#   '5. adjusted close': '36.6090',
#   '6. volume': '16557800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-28': {'1. open': '36.6500',
#   '2. high': '37.5300',
#   '3. low': '36.5300',
#   '4. close': '37.3000',
#   '5. adjusted close': '37.2685',
#   '6. volume': '20976400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-25': {'1. open': '36.5500',
#   '2. high': '37.1300',
#   '3. low': '36.3400',
#   '4. close': '36.8000',
#   '5. adjusted close': '36.7689',
#   '6. volume': '18955500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-24': {'1. open': '36.4600',
#   '2. high': '36.8300',
#   '3. low': '36.1300',
#   '4. close': '36.5600',
#   '5. adjusted close': '36.5291',
#   '6. volume': '27250700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-23': {'1. open': '35.5900',
#   '2. high': '36.7500',
#   '3. low': '35.5100',
#   '4. close': '36.3900',
#   '5. adjusted close': '36.3593',
#   '6. volume': '34380200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-22': {'1. open': '34.7700',
#   '2. high': '35.8900',
#   '3. low': '34.6700',
#   '4. close': '35.8800',
#   '5. adjusted close': '35.8497',
#   '6. volume': '35538100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-21': {'1. open': '34.2600',
#   '2. high': '34.8700',
#   '3. low': '33.9900',
#   '4. close': '34.8000',
#   '5. adjusted close': '34.7706',
#   '6. volume': '16378000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-18': {'1. open': '34.6200',
#   '2. high': '34.6200',
#   '3. low': '34.1500',
#   '4. close': '34.2400',
#   '5. adjusted close': '34.2111',
#   '6. volume': '11418100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-17': {'1. open': '34.8500',
#   '2. high': '35.1300',
#   '3. low': '34.3200',
#   '4. close': '34.6500',
#   '5. adjusted close': '34.6207',
#   '6. volume': '17054300',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-16': {'1. open': '34.4700',
#   '2. high': '34.9800',
#   '3. low': '33.8300',
#   '4. close': '34.8600',
#   '5. adjusted close': '34.8305',
#   '6. volume': '17662300',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-15': {'1. open': '34.4800',
#   '2. high': '34.6400',
#   '3. low': '34.1900',
#   '4. close': '34.3700',
#   '5. adjusted close': '34.3410',
#   '6. volume': '15976800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-14': {'1. open': '33.8100',
#   '2. high': '34.5400',
#   '3. low': '33.7200',
#   '4. close': '34.4500',
#   '5. adjusted close': '34.4209',
#   '6. volume': '10268800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-11': {'1. open': '33.6000',
#   '2. high': '34.2800',
#   '3. low': '33.5900',
#   '4. close': '33.8800',
#   '5. adjusted close': '33.8514',
#   '6. volume': '19970500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-10': {'1. open': '33.1000',
#   '2. high': '33.5600',
#   '3. low': '33.0100',
#   '4. close': '33.4500',
#   '5. adjusted close': '33.4217',
#   '6. volume': '10893700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-09': {'1. open': '32.9900',
#   '2. high': '33.4400',
#   '3. low': '32.6300',
#   '4. close': '33.2100',
#   '5. adjusted close': '33.1819',
#   '6. volume': '12442900',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-08': {'1. open': '33.1200',
#   '2. high': '33.2700',
#   '3. low': '32.5600',
#   '4. close': '32.6900',
#   '5. adjusted close': '32.6624',
#   '6. volume': '14886100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-07': {'1. open': '33.2900',
#   '2. high': '33.6400',
#   '3. low': '32.7800',
#   '4. close': '32.8300',
#   '5. adjusted close': '32.8023',
#   '6. volume': '15574100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-04': {'1. open': '33.2300',
#   '2. high': '33.5000',
#   '3. low': '32.7700',
#   '4. close': '33.4500',
#   '5. adjusted close': '33.4217',
#   '6. volume': '25181500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-03': {'1. open': '33.2400',
#   '2. high': '33.6000',
#   '3. low': '32.8500',
#   '4. close': '33.2900',
#   '5. adjusted close': '33.2619',
#   '6. volume': '21920200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-02': {'1. open': '33.8500',
#   '2. high': '33.9400',
#   '3. low': '33.1200',
#   '4. close': '33.2800',
#   '5. adjusted close': '33.2519',
#   '6. volume': '23731200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-10-01': {'1. open': '35.2200',
#   '2. high': '35.3100',
#   '3. low': '34.2000',
#   '4. close': '34.2200',
#   '5. adjusted close': '34.1911',
#   '6. volume': '17096300',
#   '7. dividend amount': '0.0150',
#   '8. split coefficient': '1.0000'},
#  '2019-09-30': {'1. open': '35.5500',
#   '2. high': '35.7900',
#   '3. low': '35.0300',
#   '4. close': '35.0300',
#   '5. adjusted close': '34.9854',
#   '6. volume': '15985400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-27': {'1. open': '35.5900',
#   '2. high': '35.6400',
#   '3. low': '34.9700',
#   '4. close': '35.5300',
#   '5. adjusted close': '35.4848',
#   '6. volume': '16175900',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-26': {'1. open': '34.8800',
#   '2. high': '35.7000',
#   '3. low': '34.6000',
#   '4. close': '35.6800',
#   '5. adjusted close': '35.6346',
#   '6. volume': '18669400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-25': {'1. open': '34.1900',
#   '2. high': '34.9200',
#   '3. low': '34.0500',
#   '4. close': '34.6800',
#   '5. adjusted close': '34.6359',
#   '6. volume': '14271700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-24': {'1. open': '34.8200',
#   '2. high': '34.8900',
#   '3. low': '34.1100',
#   '4. close': '34.2800',
#   '5. adjusted close': '34.2364',
#   '6. volume': '10497600',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-23': {'1. open': '34.7000',
#   '2. high': '34.7200',
#   '3. low': '34.2000',
#   '4. close': '34.6400',
#   '5. adjusted close': '34.5959',
#   '6. volume': '13212100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-20': {'1. open': '34.8800',
#   '2. high': '35.1000',
#   '3. low': '34.6200',
#   '4. close': '34.7500',
#   '5. adjusted close': '34.7058',
#   '6. volume': '32900200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-19': {'1. open': '35.5400',
#   '2. high': '35.8300',
#   '3. low': '34.5200',
#   '4. close': '34.6600',
#   '5. adjusted close': '34.6159',
#   '6. volume': '17989000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-18': {'1. open': '35.3700',
#   '2. high': '35.6400',
#   '3. low': '34.8300',
#   '4. close': '35.2500',
#   '5. adjusted close': '35.2051',
#   '6. volume': '13316300',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-17': {'1. open': '34.9000',
#   '2. high': '35.4500',
#   '3. low': '34.8700',
#   '4. close': '35.3600',
#   '5. adjusted close': '35.3150',
#   '6. volume': '12250100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-16': {'1. open': '35.5300',
#   '2. high': '35.6200',
#   '3. low': '34.9100',
#   '4. close': '35.2300',
#   '5. adjusted close': '35.1852',
#   '6. volume': '20161300',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-13': {'1. open': '35.5100',
#   '2. high': '36.4100',
#   '3. low': '35.5100',
#   '4. close': '35.8700',
#   '5. adjusted close': '35.8243',
#   '6. volume': '25083000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-12': {'1. open': '35.5000',
#   '2. high': '35.6000',
#   '3. low': '35.1500',
#   '4. close': '35.3900',
#   '5. adjusted close': '35.3450',
#   '6. volume': '13645700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-11': {'1. open': '35.5100',
#   '2. high': '35.6800',
#   '3. low': '34.9900',
#   '4. close': '35.1700',
#   '5. adjusted close': '35.1252',
#   '6. volume': '16367700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-10': {'1. open': '36.1100',
#   '2. high': '36.2900',
#   '3. low': '35.0900',
#   '4. close': '35.3300',
#   '5. adjusted close': '35.2850',
#   '6. volume': '22274700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-09': {'1. open': '35.3700',
#   '2. high': '36.3000',
#   '3. low': '35.3600',
#   '4. close': '36.0300',
#   '5. adjusted close': '35.9841',
#   '6. volume': '34847900',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-06': {'1. open': '34.2500',
#   '2. high': '35.2300',
#   '3. low': '34.2500',
#   '4. close': '35.1700',
#   '5. adjusted close': '35.1252',
#   '6. volume': '21399400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-05': {'1. open': '33.4200',
#   '2. high': '34.6600',
#   '3. low': '33.3900',
#   '4. close': '34.0300',
#   '5. adjusted close': '33.9867',
#   '6. volume': '42036200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-04': {'1. open': '33.2800',
#   '2. high': '33.3100',
#   '3. low': '32.8100',
#   '4. close': '33.0900',
#   '5. adjusted close': '33.0479',
#   '6. volume': '15409600',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-03': {'1. open': '33.5100',
#   '2. high': '33.8100',
#   '3. low': '32.7700',
#   '4. close': '32.8600',
#   '5. adjusted close': '32.8182',
#   '6. volume': '19116300',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-09-02': {'1. open': '33.9000',
#   '2. high': '34.1900',
#   '3. low': '33.5000',
#   '4. close': '33.5000',
#   '5. adjusted close': '33.4574',
#   '6. volume': '8366100',
#   '7. dividend amount': '0.0150',
#   '8. split coefficient': '1.0000'},
#  '2019-08-30': {'1. open': '34.5300',
#   '2. high': '34.5600',
#   '3. low': '33.7800',
#   '4. close': '33.9400',
#   '5. adjusted close': '33.8818',
#   '6. volume': '25311700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-29': {'1. open': '34.0500',
#   '2. high': '34.4700',
#   '3. low': '33.5400',
#   '4. close': '34.0900',
#   '5. adjusted close': '34.0316',
#   '6. volume': '16919500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-28': {'1. open': '33.2200',
#   '2. high': '34.0900',
#   '3. low': '33.1600',
#   '4. close': '33.9100',
#   '5. adjusted close': '33.8519',
#   '6. volume': '14492900',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-27': {'1. open': '33.1500',
#   '2. high': '33.9300',
#   '3. low': '33.0800',
#   '4. close': '33.5300',
#   '5. adjusted close': '33.4725',
#   '6. volume': '28587300',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-26': {'1. open': '33.4100',
#   '2. high': '33.4300',
#   '3. low': '32.6900',
#   '4. close': '33.1400',
#   '5. adjusted close': '33.0832',
#   '6. volume': '17811500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-23': {'1. open': '33.0900',
#   '2. high': '33.9000',
#   '3. low': '32.9300',
#   '4. close': '33.1500',
#   '5. adjusted close': '33.0932',
#   '6. volume': '26285900',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-22': {'1. open': '34.1500',
#   '2. high': '34.3300',
#   '3. low': '33.5000',
#   '4. close': '33.5400',
#   '5. adjusted close': '33.4825',
#   '6. volume': '13552000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-21': {'1. open': '34.1900',
#   '2. high': '34.3400',
#   '3. low': '33.7600',
#   '4. close': '34.0800',
#   '5. adjusted close': '34.0216',
#   '6. volume': '19548800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-20': {'1. open': '34.3700',
#   '2. high': '34.4500',
#   '3. low': '33.5500',
#   '4. close': '33.8200',
#   '5. adjusted close': '33.7620',
#   '6. volume': '17302100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-19': {'1. open': '34.6500',
#   '2. high': '34.8700',
#   '3. low': '33.9100',
#   '4. close': '34.2000',
#   '5. adjusted close': '34.1414',
#   '6. volume': '22628600',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-16': {'1. open': '34.8000',
#   '2. high': '34.8600',
#   '3. low': '34.1300',
#   '4. close': '34.3500',
#   '5. adjusted close': '34.2911',
#   '6. volume': '14343000',
#   '7. dividend amount': '0.2393',
#   '8. split coefficient': '1.0000'},
#  '2019-08-15': {'1. open': '35.4800',
#   '2. high': '35.4800',
#   '3. low': '34.8100',
#   '4. close': '35.0000',
#   '5. adjusted close': '34.7011',
#   '6. volume': '19086500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-14': {'1. open': '35.4000',
#   '2. high': '35.5700',
#   '3. low': '35.0200',
#   '4. close': '35.1000',
#   '5. adjusted close': '34.8003',
#   '6. volume': '20769200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-13': {'1. open': '35.1800',
#   '2. high': '36.1200',
#   '3. low': '35.1200',
#   '4. close': '35.8900',
#   '5. adjusted close': '35.5835',
#   '6. volume': '13635000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-12': {'1. open': '36.0000',
#   '2. high': '36.0400',
#   '3. low': '35.1900',
#   '4. close': '35.2000',
#   '5. adjusted close': '34.8994',
#   '6. volume': '20246800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-09': {'1. open': '36.9900',
#   '2. high': '37.0000',
#   '3. low': '36.3500',
#   '4. close': '36.7200',
#   '5. adjusted close': '36.4064',
#   '6. volume': '11884800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-08': {'1. open': '37.0000',
#   '2. high': '37.3500',
#   '3. low': '36.6700',
#   '4. close': '37.0000',
#   '5. adjusted close': '36.6840',
#   '6. volume': '30196800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-07': {'1. open': '35.0700',
#   '2. high': '36.8000',
#   '3. low': '34.9600',
#   '4. close': '36.8000',
#   '5. adjusted close': '36.4857',
#   '6. volume': '32065800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-06': {'1. open': '34.9400',
#   '2. high': '35.4900',
#   '3. low': '34.8000',
#   '4. close': '35.4900',
#   '5. adjusted close': '35.1869',
#   '6. volume': '17746200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-05': {'1. open': '34.2000',
#   '2. high': '34.7200',
#   '3. low': '34.0400',
#   '4. close': '34.4500',
#   '5. adjusted close': '34.1558',
#   '6. volume': '21294600',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-02': {'1. open': '35.0000',
#   '2. high': '35.2000',
#   '3. low': '34.5800',
#   '4. close': '34.9300',
#   '5. adjusted close': '34.6317',
#   '6. volume': '27808000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-08-01': {'1. open': '35.2100',
#   '2. high': '36.1200',
#   '3. low': '34.8800',
#   '4. close': '34.8800',
#   '5. adjusted close': '34.5821',
#   '6. volume': '32801400',
#   '7. dividend amount': '0.0150',
#   '8. split coefficient': '1.0000'},
#  '2019-07-31': {'1. open': '35.7400',
#   '2. high': '35.7800',
#   '3. low': '34.7000',
#   '4. close': '34.8200',
#   '5. adjusted close': '34.5078',
#   '6. volume': '35542000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-30': {'1. open': '36.8000',
#   '2. high': '36.8000',
#   '3. low': '35.6600',
#   '4. close': '35.7700',
#   '5. adjusted close': '35.4493',
#   '6. volume': '44206600',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-29': {'1. open': '36.7600',
#   '2. high': '37.2700',
#   '3. low': '36.4500',
#   '4. close': '37.0000',
#   '5. adjusted close': '36.6682',
#   '6. volume': '20228700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-26': {'1. open': '36.4800',
#   '2. high': '37.0800',
#   '3. low': '36.0100',
#   '4. close': '36.8500',
#   '5. adjusted close': '36.5196',
#   '6. volume': '23826000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-25': {'1. open': '37.6500',
#   '2. high': '37.6500',
#   '3. low': '35.9800',
#   '4. close': '36.2000',
#   '5. adjusted close': '35.8754',
#   '6. volume': '22380700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-24': {'1. open': '37.5000',
#   '2. high': '37.7500',
#   '3. low': '37.1300',
#   '4. close': '37.3500',
#   '5. adjusted close': '37.0151',
#   '6. volume': '14689500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-23': {'1. open': '37.2500',
#   '2. high': '37.5500',
#   '3. low': '36.7300',
#   '4. close': '37.3800',
#   '5. adjusted close': '37.0448',
#   '6. volume': '21128500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-22': {'1. open': '36.6900',
#   '2. high': '37.2500',
#   '3. low': '36.6200',
#   '4. close': '37.0200',
#   '5. adjusted close': '36.6881',
#   '6. volume': '18663100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-19': {'1. open': '37.0800',
#   '2. high': '37.2800',
#   '3. low': '36.4000',
#   '4. close': '36.4000',
#   '5. adjusted close': '36.0736',
#   '6. volume': '17145500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-18': {'1. open': '36.4700',
#   '2. high': '37.3700',
#   '3. low': '36.4600',
#   '4. close': '37.3700',
#   '5. adjusted close': '37.0349',
#   '6. volume': '16209600',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-17': {'1. open': '36.5900',
#   '2. high': '36.9200',
#   '3. low': '36.3800',
#   '4. close': '36.4000',
#   '5. adjusted close': '36.0736',
#   '6. volume': '23122700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-16': {'1. open': '36.4000',
#   '2. high': '36.6500',
#   '3. low': '36.2100',
#   '4. close': '36.5000',
#   '5. adjusted close': '36.1727',
#   '6. volume': '17844700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-15': {'1. open': '36.6800',
#   '2. high': '36.7000',
#   '3. low': '36.1200',
#   '4. close': '36.3600',
#   '5. adjusted close': '36.0340',
#   '6. volume': '16642300',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-12': {'1. open': '37.4500',
#   '2. high': '37.4600',
#   '3. low': '36.4600',
#   '4. close': '36.4600',
#   '5. adjusted close': '36.1331',
#   '6. volume': '18723300',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-11': {'1. open': '36.9700',
#   '2. high': '37.1500',
#   '3. low': '36.5800',
#   '4. close': '37.1500',
#   '5. adjusted close': '36.8169',
#   '6. volume': '15289000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-10': {'1. open': '37.5300',
#   '2. high': '37.7200',
#   '3. low': '36.9500',
#   '4. close': '37.2000',
#   '5. adjusted close': '36.8664',
#   '6. volume': '22765400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-08': {'1. open': '37.4700',
#   '2. high': '37.5000',
#   '3. low': '37.0600',
#   '4. close': '37.3000',
#   '5. adjusted close': '36.9655',
#   '6. volume': '9918400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-05': {'1. open': '36.8400',
#   '2. high': '37.4500',
#   '3. low': '36.6700',
#   '4. close': '37.4000',
#   '5. adjusted close': '37.0646',
#   '6. volume': '14345800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-04': {'1. open': '36.7700',
#   '2. high': '37.5000',
#   '3. low': '36.7100',
#   '4. close': '36.9900',
#   '5. adjusted close': '36.6583',
#   '6. volume': '23138400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-03': {'1. open': '35.7000',
#   '2. high': '36.6500',
#   '3. low': '35.6300',
#   '4. close': '36.5700',
#   '5. adjusted close': '36.2421',
#   '6. volume': '17651400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-02': {'1. open': '36.0500',
#   '2. high': '36.3200',
#   '3. low': '35.7100',
#   '4. close': '35.9500',
#   '5. adjusted close': '35.6277',
#   '6. volume': '18830100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-07-01': {'1. open': '36.7700',
#   '2. high': '36.7700',
#   '3. low': '35.9400',
#   '4. close': '36.0800',
#   '5. adjusted close': '35.7565',
#   '6. volume': '15922800',
#   '7. dividend amount': '0.0150',
#   '8. split coefficient': '1.0000'},
#  '2019-06-28': {'1. open': '36.4500',
#   '2. high': '36.5900',
#   '3. low': '36.1400',
#   '4. close': '36.2600',
#   '5. adjusted close': '35.9200',
#   '6. volume': '17615100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-27': {'1. open': '36.2000',
#   '2. high': '36.4300',
#   '3. low': '35.7000',
#   '4. close': '36.2500',
#   '5. adjusted close': '35.9101',
#   '6. volume': '20630300',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-26': {'1. open': '35.8500',
#   '2. high': '36.5000',
#   '3. low': '35.7300',
#   '4. close': '36.5000',
#   '5. adjusted close': '36.1578',
#   '6. volume': '32869700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-25': {'1. open': '36.0000',
#   '2. high': '36.2300',
#   '3. low': '35.4800',
#   '4. close': '35.6500',
#   '5. adjusted close': '35.3157',
#   '6. volume': '23790600',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-24': {'1. open': '36.2400',
#   '2. high': '36.5000',
#   '3. low': '35.7900',
#   '4. close': '36.1000',
#   '5. adjusted close': '35.7615',
#   '6. volume': '22715800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-21': {'1. open': '35.5800',
#   '2. high': '36.1800',
#   '3. low': '35.5000',
#   '4. close': '36.1800',
#   '5. adjusted close': '35.8408',
#   '6. volume': '27455000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-19': {'1. open': '34.6400',
#   '2. high': '35.4900',
#   '3. low': '34.4700',
#   '4. close': '35.3800',
#   '5. adjusted close': '35.0483',
#   '6. volume': '23278900',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-18': {'1. open': '34.3500',
#   '2. high': '34.8300',
#   '3. low': '34.1800',
#   '4. close': '34.8300',
#   '5. adjusted close': '34.5034',
#   '6. volume': '22791000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-17': {'1. open': '33.9000',
#   '2. high': '34.3200',
#   '3. low': '33.8100',
#   '4. close': '33.9500',
#   '5. adjusted close': '33.6317',
#   '6. volume': '15638100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-14': {'1. open': '33.9000',
#   '2. high': '34.0700',
#   '3. low': '33.4800',
#   '4. close': '33.9900',
#   '5. adjusted close': '33.6713',
#   '6. volume': '18775100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-13': {'1. open': '34.5500',
#   '2. high': '34.5800',
#   '3. low': '33.7100',
#   '4. close': '33.9800',
#   '5. adjusted close': '33.6614',
#   '6. volume': '36877200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-12': {'1. open': '34.8000',
#   '2. high': '35.1200',
#   '3. low': '34.4700',
#   '4. close': '34.6000',
#   '5. adjusted close': '34.2756',
#   '6. volume': '17637000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-11': {'1. open': '34.8500',
#   '2. high': '34.9800',
#   '3. low': '34.2400',
#   '4. close': '34.8000',
#   '5. adjusted close': '34.4737',
#   '6. volume': '29136500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-10': {'1. open': '34.8500',
#   '2. high': '34.8700',
#   '3. low': '34.1100',
#   '4. close': '34.6300',
#   '5. adjusted close': '34.3053',
#   '6. volume': '18283400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-07': {'1. open': '34.7800',
#   '2. high': '35.2800',
#   '3. low': '34.6700',
#   '4. close': '35.0700',
#   '5. adjusted close': '34.7412',
#   '6. volume': '13355900',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-06': {'1. open': '34.6900',
#   '2. high': '34.8900',
#   '3. low': '34.3800',
#   '4. close': '34.7000',
#   '5. adjusted close': '34.3746',
#   '6. volume': '11449900',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-05': {'1. open': '35.0900',
#   '2. high': '35.1600',
#   '3. low': '34.2700',
#   '4. close': '34.3400',
#   '5. adjusted close': '34.0180',
#   '6. volume': '12193600',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-04': {'1. open': '35.2000',
#   '2. high': '35.3000',
#   '3. low': '34.7600',
#   '4. close': '35.0200',
#   '5. adjusted close': '34.6916',
#   '6. volume': '16554600',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-06-03': {'1. open': '35.2000',
#   '2. high': '35.3200',
#   '3. low': '34.7300',
#   '4. close': '35.0800',
#   '5. adjusted close': '34.7511',
#   '6. volume': '18939200',
#   '7. dividend amount': '0.0150',
#   '8. split coefficient': '1.0000'},
#  '2019-05-31': {'1. open': '34.8900',
#   '2. high': '35.4000',
#   '3. low': '34.7500',
#   '4. close': '35.0000',
#   '5. adjusted close': '34.6570',
#   '6. volume': '18216700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-30': {'1. open': '34.8100',
#   '2. high': '35.2200',
#   '3. low': '34.6800',
#   '4. close': '35.0800',
#   '5. adjusted close': '34.7362',
#   '6. volume': '15947600',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-29': {'1. open': '33.8500',
#   '2. high': '34.8900',
#   '3. low': '33.8500',
#   '4. close': '34.7200',
#   '5. adjusted close': '34.3797',
#   '6. volume': '28132700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-28': {'1. open': '33.2800',
#   '2. high': '34.0800',
#   '3. low': '33.1200',
#   '4. close': '34.0800',
#   '5. adjusted close': '33.7460',
#   '6. volume': '32564800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-27': {'1. open': '33.3300',
#   '2. high': '33.5800',
#   '3. low': '33.0300',
#   '4. close': '33.1500',
#   '5. adjusted close': '32.8251',
#   '6. volume': '10607500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-24': {'1. open': '33.8000',
#   '2. high': '33.8500',
#   '3. low': '33.0100',
#   '4. close': '33.0300',
#   '5. adjusted close': '32.7063',
#   '6. volume': '11538100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-23': {'1. open': '33.3900',
#   '2. high': '33.7200',
#   '3. low': '33.1300',
#   '4. close': '33.5300',
#   '5. adjusted close': '33.2014',
#   '6. volume': '15793700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-22': {'1. open': '33.7000',
#   '2. high': '33.8000',
#   '3. low': '32.9700',
#   '4. close': '33.6000',
#   '5. adjusted close': '33.2707',
#   '6. volume': '13175500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-21': {'1. open': '32.4000',
#   '2. high': '33.5900',
#   '3. low': '32.3600',
#   '4. close': '33.5700',
#   '5. adjusted close': '33.2410',
#   '6. volume': '23455000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-20': {'1. open': '31.7000',
#   '2. high': '32.3800',
#   '3. low': '31.3900',
#   '4. close': '32.3200',
#   '5. adjusted close': '32.0032',
#   '6. volume': '24166700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-17': {'1. open': '31.3700',
#   '2. high': '32.0000',
#   '3. low': '31.1100',
#   '4. close': '31.5000',
#   '5. adjusted close': '31.1913',
#   '6. volume': '23815600',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-16': {'1. open': '31.5000',
#   '2. high': '31.6700',
#   '3. low': '31.1600',
#   '4. close': '31.4400',
#   '5. adjusted close': '31.1319',
#   '6. volume': '18017400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-15': {'1. open': '31.5100',
#   '2. high': '31.8500',
#   '3. low': '31.1400',
#   '4. close': '31.8500',
#   '5. adjusted close': '31.5378',
#   '6. volume': '21154800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-14': {'1. open': '32.0700',
#   '2. high': '32.1800',
#   '3. low': '31.6300',
#   '4. close': '31.7500',
#   '5. adjusted close': '31.4388',
#   '6. volume': '13339700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-13': {'1. open': '31.7200',
#   '2. high': '32.0500',
#   '3. low': '31.6600',
#   '4. close': '31.9000',
#   '5. adjusted close': '31.5873',
#   '6. volume': '19063500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-10': {'1. open': '32.4900',
#   '2. high': '32.8000',
#   '3. low': '32.0300',
#   '4. close': '32.4100',
#   '5. adjusted close': '32.0923',
#   '6. volume': '14490800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-09': {'1. open': '32.5700',
#   '2. high': '32.8700',
#   '3. low': '32.2400',
#   '4. close': '32.5600',
#   '5. adjusted close': '32.2409',
#   '6. volume': '21662400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-08': {'1. open': '32.7400',
#   '2. high': '33.3800',
#   '3. low': '32.7400',
#   '4. close': '32.9700',
#   '5. adjusted close': '32.6469',
#   '6. volume': '18049500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-07': {'1. open': '32.7000',
#   '2. high': '32.7200',
#   '3. low': '31.9500',
#   '4. close': '32.6000',
#   '5. adjusted close': '32.2805',
#   '6. volume': '29106700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-06': {'1. open': '33.3400',
#   '2. high': '33.4900',
#   '3. low': '32.9300',
#   '4. close': '32.9700',
#   '5. adjusted close': '32.6469',
#   '6. volume': '14639700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-03': {'1. open': '34.2000',
#   '2. high': '34.2800',
#   '3. low': '33.6400',
#   '4. close': '33.7100',
#   '5. adjusted close': '33.3796',
#   '6. volume': '31030200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-05-02': {'1. open': '33.6700',
#   '2. high': '34.2200',
#   '3. low': '33.5900',
#   '4. close': '34.0400',
#   '5. adjusted close': '33.7064',
#   '6. volume': '14629500',
#   '7. dividend amount': '0.0150',
#   '8. split coefficient': '1.0000'},
#  '2019-04-30': {'1. open': '33.6900',
#   '2. high': '34.0300',
#   '3. low': '33.4300',
#   '4. close': '33.8300',
#   '5. adjusted close': '33.4836',
#   '6. volume': '13501100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-29': {'1. open': '33.9500',
#   '2. high': '34.1100',
#   '3. low': '33.3900',
#   '4. close': '33.5300',
#   '5. adjusted close': '33.1866',
#   '6. volume': '11055200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-26': {'1. open': '33.8100',
#   '2. high': '33.9200',
#   '3. low': '33.4100',
#   '4. close': '33.8000',
#   '5. adjusted close': '33.4539',
#   '6. volume': '10071700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-25': {'1. open': '33.0200',
#   '2. high': '33.8000',
#   '3. low': '32.6400',
#   '4. close': '33.7200',
#   '5. adjusted close': '33.3747',
#   '6. volume': '19588900',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-24': {'1. open': '33.1800',
#   '2. high': '33.2400',
#   '3. low': '32.6800',
#   '4. close': '33.2100',
#   '5. adjusted close': '32.8699',
#   '6. volume': '14647000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-23': {'1. open': '33.0000',
#   '2. high': '33.4500',
#   '3. low': '33.0000',
#   '4. close': '33.1600',
#   '5. adjusted close': '32.8204',
#   '6. volume': '13401400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-22': {'1. open': '32.7700',
#   '2. high': '33.1500',
#   '3. low': '32.3900',
#   '4. close': '32.7400',
#   '5. adjusted close': '32.4047',
#   '6. volume': '10063200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-18': {'1. open': '32.5200',
#   '2. high': '33.2000',
#   '3. low': '32.1200',
#   '4. close': '32.8300',
#   '5. adjusted close': '32.4938',
#   '6. volume': '17515300',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-17': {'1. open': '33.0000',
#   '2. high': '33.2000',
#   '3. low': '32.0000',
#   '4. close': '32.3900',
#   '5. adjusted close': '32.0583',
#   '6. volume': '35979200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-16': {'1. open': '32.7200',
#   '2. high': '33.4600',
#   '3. low': '32.7200',
#   '4. close': '32.9000',
#   '5. adjusted close': '32.5631',
#   '6. volume': '16992700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-15': {'1. open': '33.2400',
#   '2. high': '33.3300',
#   '3. low': '32.6400',
#   '4. close': '32.9300',
#   '5. adjusted close': '32.5928',
#   '6. volume': '16527700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-12': {'1. open': '33.0000',
#   '2. high': '33.8200',
#   '3. low': '32.6500',
#   '4. close': '32.9500',
#   '5. adjusted close': '32.6126',
#   '6. volume': '29457500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-11': {'1. open': '33.8200',
#   '2. high': '34.0400',
#   '3. low': '33.1100',
#   '4. close': '33.3000',
#   '5. adjusted close': '32.9590',
#   '6. volume': '12091400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-10': {'1. open': '34.4000',
#   '2. high': '34.4400',
#   '3. low': '33.8100',
#   '4. close': '34.0900',
#   '5. adjusted close': '33.7409',
#   '6. volume': '26315900',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-09': {'1. open': '34.2000',
#   '2. high': '34.2200',
#   '3. low': '33.6100',
#   '4. close': '34.1500',
#   '5. adjusted close': '33.8003',
#   '6. volume': '13385100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-08': {'1. open': '34.6000',
#   '2. high': '34.6700',
#   '3. low': '34.1500',
#   '4. close': '34.3400',
#   '5. adjusted close': '33.9884',
#   '6. volume': '9190600',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-05': {'1. open': '34.0000',
#   '2. high': '34.6700',
#   '3. low': '33.8000',
#   '4. close': '34.5500',
#   '5. adjusted close': '34.1962',
#   '6. volume': '16192100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-04': {'1. open': '33.6900',
#   '2. high': '34.0900',
#   '3. low': '33.2500',
#   '4. close': '33.8200',
#   '5. adjusted close': '33.4737',
#   '6. volume': '18053600',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-03': {'1. open': '34.0400',
#   '2. high': '34.1900',
#   '3. low': '33.1700',
#   '4. close': '33.3200',
#   '5. adjusted close': '32.9788',
#   '6. volume': '19468200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-02': {'1. open': '34.2500',
#   '2. high': '34.3300',
#   '3. low': '33.5300',
#   '4. close': '33.6200',
#   '5. adjusted close': '33.2757',
#   '6. volume': '16358100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-04-01': {'1. open': '34.7000',
#   '2. high': '34.8000',
#   '3. low': '34.0000',
#   '4. close': '34.1600',
#   '5. adjusted close': '33.8102',
#   '6. volume': '17229600',
#   '7. dividend amount': '0.0150',
#   '8. split coefficient': '1.0000'},
#  '2019-03-29': {'1. open': '34.5200',
#   '2. high': '34.5500',
#   '3. low': '33.9200',
#   '4. close': '34.4300',
#   '5. adjusted close': '34.0626',
#   '6. volume': '19700400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-28': {'1. open': '32.9000',
#   '2. high': '34.3400',
#   '3. low': '32.6500',
#   '4. close': '34.1000',
#   '5. adjusted close': '33.7361',
#   '6. volume': '31144800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-27': {'1. open': '33.4300',
#   '2. high': '33.6400',
#   '3. low': '32.7900',
#   '4. close': '32.8000',
#   '5. adjusted close': '32.4500',
#   '6. volume': '28321300',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-26': {'1. open': '34.0000',
#   '2. high': '34.1100',
#   '3. low': '33.5000',
#   '4. close': '33.9500',
#   '5. adjusted close': '33.5877',
#   '6. volume': '16071700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-25': {'1. open': '33.4900',
#   '2. high': '34.1200',
#   '3. low': '33.3000',
#   '4. close': '33.6000',
#   '5. adjusted close': '33.2414',
#   '6. volume': '19909900',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-22': {'1. open': '34.0500',
#   '2. high': '34.1200',
#   '3. low': '33.3600',
#   '4. close': '33.5500',
#   '5. adjusted close': '33.1920',
#   '6. volume': '30631500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-21': {'1. open': '35.3100',
#   '2. high': '35.4100',
#   '3. low': '34.1000',
#   '4. close': '34.5700',
#   '5. adjusted close': '34.2011',
#   '6. volume': '31558000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-20': {'1. open': '36.0600',
#   '2. high': '36.2200',
#   '3. low': '35.1900',
#   '4. close': '35.1900',
#   '5. adjusted close': '34.8145',
#   '6. volume': '26182500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-19': {'1. open': '37.0000',
#   '2. high': '37.0000',
#   '3. low': '36.0000',
#   '4. close': '36.0000',
#   '5. adjusted close': '35.6158',
#   '6. volume': '35023800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-18': {'1. open': '36.8600',
#   '2. high': '37.0600',
#   '3. low': '36.7400',
#   '4. close': '36.8600',
#   '5. adjusted close': '36.4667',
#   '6. volume': '11303100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-15': {'1. open': '36.7300',
#   '2. high': '37.1700',
#   '3. low': '36.4800',
#   '4. close': '36.8000',
#   '5. adjusted close': '36.4073',
#   '6. volume': '19106000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-14': {'1. open': '37.4000',
#   '2. high': '37.4000',
#   '3. low': '36.4400',
#   '4. close': '36.8100',
#   '5. adjusted close': '36.4172',
#   '6. volume': '17809100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-13': {'1. open': '36.8200',
#   '2. high': '37.6700',
#   '3. low': '36.7000',
#   '4. close': '37.4000',
#   '5. adjusted close': '37.0009',
#   '6. volume': '22202800',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-12': {'1. open': '36.9200',
#   '2. high': '37.0000',
#   '3. low': '36.5900',
#   '4. close': '37.0000',
#   '5. adjusted close': '36.6052',
#   '6. volume': '13109300',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-11': {'1. open': '35.8500',
#   '2. high': '37.0200',
#   '3. low': '35.8300',
#   '4. close': '36.9200',
#   '5. adjusted close': '36.5260',
#   '6. volume': '19995500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-08': {'1. open': '35.1200',
#   '2. high': '35.8900',
#   '3. low': '34.8500',
#   '4. close': '35.7500',
#   '5. adjusted close': '35.3685',
#   '6. volume': '13565000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-07': {'1. open': '34.8000',
#   '2. high': '35.5400',
#   '3. low': '34.6700',
#   '4. close': '35.3300',
#   '5. adjusted close': '34.9530',
#   '6. volume': '18963500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-03-01': {'1. open': '35.4900',
#   '2. high': '35.5900',
#   '3. low': '34.8400',
#   '4. close': '34.8400',
#   '5. adjusted close': '34.4682',
#   '6. volume': '16152300',
#   '7. dividend amount': '0.0150',
#   '8. split coefficient': '1.0000'},
#  '2019-02-28': {'1. open': '35.9300',
#   '2. high': '36.0200',
#   '3. low': '35.1700',
#   '4. close': '35.2300',
#   '5. adjusted close': '34.8392',
#   '6. volume': '18012500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-02-27': {'1. open': '36.2200',
#   '2. high': '36.3700',
#   '3. low': '35.9100',
#   '4. close': '35.9100',
#   '5. adjusted close': '35.5117',
#   '6. volume': '10132700',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-02-26': {'1. open': '36.1900',
#   '2. high': '36.4200',
#   '3. low': '36.0900',
#   '4. close': '36.2300',
#   '5. adjusted close': '35.8281',
#   '6. volume': '8053100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-02-25': {'1. open': '36.7500',
#   '2. high': '36.8800',
#   '3. low': '36.0800',
#   '4. close': '36.1000',
#   '5. adjusted close': '35.6996',
#   '6. volume': '12453300',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-02-22': {'1. open': '36.5300',
#   '2. high': '36.6600',
#   '3. low': '36.2300',
#   '4. close': '36.6600',
#   '5. adjusted close': '36.2533',
#   '6. volume': '17459100',
#   '7. dividend amount': '0.7494',
#   '8. split coefficient': '1.0000'},
#  '2019-02-21': {'1. open': '37.6500',
#   '2. high': '37.9500',
#   '3. low': '37.2600',
#   '4. close': '37.9500',
#   '5. adjusted close': '36.7880',
#   '6. volume': '25310600',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-02-20': {'1. open': '38.0300',
#   '2. high': '38.3800',
#   '3. low': '37.2700',
#   '4. close': '37.2700',
#   '5. adjusted close': '36.1288',
#   '6. volume': '28751200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-02-19': {'1. open': '37.3000',
#   '2. high': '38.0000',
#   '3. low': '37.1900',
#   '4. close': '37.7500',
#   '5. adjusted close': '36.5941',
#   '6. volume': '22551400',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2019-02-18': {'1. open': '37.3500',
#   '2. high': '37.5000',
#   '3. low': '36.9000',
# ...
#  '2016-03-09': {'1. open': '19.5697',
#   '2. high': '19.8121',
#   '3. low': '18.6970',
#   '4. close': '18.6970',
#   '5. adjusted close': '16.0943',
#   '6. volume': '37545090',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-03-08': {'1. open': '18.8364',
#   '2. high': '19.6242',
#   '3. low': '18.6788',
#   '4. close': '19.3394',
#   '5. adjusted close': '16.6473',
#   '6. volume': '31871730',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-03-07': {'1. open': '19.0000',
#   '2. high': '19.0303',
#   '3. low': '18.3636',
#   '4. close': '18.9151',
#   '5. adjusted close': '16.2821',
#   '6. volume': '30214470',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-03-04': {'1. open': '18.1152',
#   '2. high': '19.6606',
#   '3. low': '18.1152',
#   '4. close': '19.0000',
#   '5. adjusted close': '16.3551',
#   '6. volume': '82980480',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-03-03': {'1. open': '16.6667',
#   '2. high': '18.1636',
#   '3. low': '16.6606',
#   '4. close': '18.1152',
#   '5. adjusted close': '15.5935',
#   '6. volume': '69189780',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-03-02': {'1. open': '16.1212',
#   '2. high': '16.5394',
#   '3. low': '15.8970',
#   '4. close': '16.4848',
#   '5. adjusted close': '14.1901',
#   '6. volume': '40292340',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-03-01': {'1. open': '15.5394',
#   '2. high': '16.1091',
#   '3. low': '15.4545',
#   '4. close': '16.1091',
#   '5. adjusted close': '13.8667',
#   '6. volume': '36920235',
#   '7. dividend amount': '0.0150',
#   '8. split coefficient': '1.0000'},
#  '2016-02-29': {'1. open': '15.2121',
#   '2. high': '15.4485',
#   '3. low': '15.0303',
#   '4. close': '15.3939',
#   '5. adjusted close': '13.2381',
#   '6. volume': '34760550',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-26': {'1. open': '15.0727',
#   '2. high': '15.2606',
#   '3. low': '14.8606',
#   '4. close': '14.9697',
#   '5. adjusted close': '12.8733',
#   '6. volume': '15535410',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-25': {'1. open': '14.8121',
#   '2. high': '15.2364',
#   '3. low': '14.7091',
#   '4. close': '14.9697',
#   '5. adjusted close': '12.8733',
#   '6. volume': '17569035',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-24': {'1. open': '14.8727',
#   '2. high': '15.0606',
#   '3. low': '14.6364',
#   '4. close': '14.9576',
#   '5. adjusted close': '12.8629',
#   '6. volume': '17499735',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-23': {'1. open': '15.1697',
#   '2. high': '15.4545',
#   '3. low': '14.9818',
#   '4. close': '15.0849',
#   '5. adjusted close': '12.9724',
#   '6. volume': '20040570',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-22': {'1. open': '15.1212',
#   '2. high': '15.3939',
#   '3. low': '15.0000',
#   '4. close': '15.3030',
#   '5. adjusted close': '13.1599',
#   '6. volume': '42384375',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-19': {'1. open': '14.4667',
#   '2. high': '14.8061',
#   '3. low': '14.4000',
#   '4. close': '14.7091',
#   '5. adjusted close': '12.6492',
#   '6. volume': '20481780',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-18': {'1. open': '15.0788',
#   '2. high': '15.0909',
#   '3. low': '14.7576',
#   '4. close': '14.9333',
#   '5. adjusted close': '12.8420',
#   '6. volume': '30770190',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-17': {'1. open': '15.2727',
#   '2. high': '15.6727',
#   '3. low': '14.9394',
#   '4. close': '15.2424',
#   '5. adjusted close': '13.1078',
#   '6. volume': '41933430',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-16': {'1. open': '14.7576',
#   '2. high': '15.3273',
#   '3. low': '14.6424',
#   '4. close': '15.0788',
#   '5. adjusted close': '12.9671',
#   '6. volume': '31493550',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-15': {'1. open': '15.0242',
#   '2. high': '15.0546',
#   '3. low': '14.7212',
#   '4. close': '14.7212',
#   '5. adjusted close': '12.6596',
#   '6. volume': '10821195',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-12': {'1. open': '14.7636',
#   '2. high': '14.8000',
#   '3. low': '14.4970',
#   '4. close': '14.7697',
#   '5. adjusted close': '12.7013',
#   '6. volume': '16816305',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-11': {'1. open': '14.8061',
#   '2. high': '14.8909',
#   '3. low': '14.4909',
#   '4. close': '14.6545',
#   '5. adjusted close': '12.6023',
#   '6. volume': '17631735',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-10': {'1. open': '14.8364',
#   '2. high': '15.1212',
#   '3. low': '14.7576',
#   '4. close': '15.1030',
#   '5. adjusted close': '12.9879',
#   '6. volume': '12062655',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-05': {'1. open': '14.8485',
#   '2. high': '15.2424',
#   '3. low': '14.7394',
#   '4. close': '15.0303',
#   '5. adjusted close': '12.9254',
#   '6. volume': '23766930',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-04': {'1. open': '14.9091',
#   '2. high': '15.3091',
#   '3. low': '14.4303',
#   '4. close': '14.8848',
#   '5. adjusted close': '12.8003',
#   '6. volume': '37742760',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-03': {'1. open': '14.4182',
#   '2. high': '14.7515',
#   '3. low': '14.3939',
#   '4. close': '14.6727',
#   '5. adjusted close': '12.6179',
#   '6. volume': '38135460',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-02': {'1. open': '14.8242',
#   '2. high': '14.8485',
#   '3. low': '14.0909',
#   '4. close': '14.3273',
#   '5. adjusted close': '12.3209',
#   '6. volume': '74752260',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-02-01': {'1. open': '14.9758',
#   '2. high': '15.4364',
#   '3. low': '14.8182',
#   '4. close': '15.4364',
#   '5. adjusted close': '13.2747',
#   '6. volume': '19258800',
#   '7. dividend amount': '0.0150',
#   '8. split coefficient': '1.0000'},
#  '2016-01-29': {'1. open': '14.6061',
#   '2. high': '15.1212',
#   '3. low': '14.5455',
#   '4. close': '15.1212',
#   '5. adjusted close': '12.9907',
#   '6. volume': '30569220',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-28': {'1. open': '14.5091',
#   '2. high': '14.5879',
#   '3. low': '14.3030',
#   '4. close': '14.4485',
#   '5. adjusted close': '12.4128',
#   '6. volume': '16516005',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-27': {'1. open': '14.2242',
#   '2. high': '14.5576',
#   '3. low': '14.0788',
#   '4. close': '14.3515',
#   '5. adjusted close': '12.3294',
#   '6. volume': '23269455',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-26': {'1. open': '13.9697',
#   '2. high': '14.2970',
#   '3. low': '13.8909',
#   '4. close': '14.2970',
#   '5. adjusted close': '12.2826',
#   '6. volume': '18401130',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-22': {'1. open': '14.1515',
#   '2. high': '14.3333',
#   '3. low': '14.0667',
#   '4. close': '14.1454',
#   '5. adjusted close': '12.1524',
#   '6. volume': '15794460',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-21': {'1. open': '13.9394',
#   '2. high': '14.2242',
#   '3. low': '13.9091',
#   '4. close': '14.0121',
#   '5. adjusted close': '12.0379',
#   '6. volume': '29577240',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-20': {'1. open': '13.9394',
#   '2. high': '14.0727',
#   '3. low': '13.8242',
#   '4. close': '13.9818',
#   '5. adjusted close': '12.0118',
#   '6. volume': '36861825',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-19': {'1. open': '14.5636',
#   '2. high': '14.6485',
#   '3. low': '14.0849',
#   '4. close': '14.1818',
#   '5. adjusted close': '12.1837',
#   '6. volume': '16685460',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-18': {'1. open': '14.5455',
#   '2. high': '14.5879',
#   '3. low': '14.3273',
#   '4. close': '14.3273',
#   '5. adjusted close': '12.3086',
#   '6. volume': '10937685',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-15': {'1. open': '14.6061',
#   '2. high': '14.6667',
#   '3. low': '14.3697',
#   '4. close': '14.4970',
#   '5. adjusted close': '12.4544',
#   '6. volume': '30337560',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-14': {'1. open': '14.7273',
#   '2. high': '14.8970',
#   '3. low': '14.3394',
#   '4. close': '14.8848',
#   '5. adjusted close': '12.7876',
#   '6. volume': '23442375',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-13': {'1. open': '15.0667',
#   '2. high': '15.1515',
#   '3. low': '14.5818',
#   '4. close': '14.6727',
#   '5. adjusted close': '12.6054',
#   '6. volume': '19543260',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-12': {'1. open': '15.0303',
#   '2. high': '15.1758',
#   '3. low': '14.7939',
#   '4. close': '14.9030',
#   '5. adjusted close': '12.8032',
#   '6. volume': '18183000',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-11': {'1. open': '15.0970',
#   '2. high': '15.1697',
#   '3. low': '14.8061',
#   '4. close': '14.8364',
#   '5. adjusted close': '12.7460',
#   '6. volume': '19219695',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-08': {'1. open': '15.1212',
#   '2. high': '15.3030',
#   '3. low': '15.0121',
#   '4. close': '15.0121',
#   '5. adjusted close': '12.8970',
#   '6. volume': '18087465',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-07': {'1. open': '15.0909',
#   '2. high': '15.3273',
#   '3. low': '15.0061',
#   '4. close': '15.0061',
#   '5. adjusted close': '12.8918',
#   '6. volume': '28766430',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-06': {'1. open': '15.1515',
#   '2. high': '15.6545',
#   '3. low': '15.0303',
#   '4. close': '15.2970',
#   '5. adjusted close': '13.1417',
#   '6. volume': '33520575',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-05': {'1. open': '15.3939',
#   '2. high': '15.6242',
#   '3. low': '15.2000',
#   '4. close': '15.3576',
#   '5. adjusted close': '13.1938',
#   '6. volume': '21093105',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2016-01-04': {'1. open': '15.7091',
#   '2. high': '15.8121',
#   '3. low': '15.2303',
#   '4. close': '15.2303',
#   '5. adjusted close': '13.0844',
#   '6. volume': '38071770',
#   '7. dividend amount': '0.0150',
#   '8. split coefficient': '1.0000'},
#  '2015-12-30': {'1. open': '16.0788',
#   '2. high': '16.0788',
#   '3. low': '15.8000',
#   '4. close': '15.9576',
#   '5. adjusted close': '13.6964',
#   '6. volume': '21126765',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-29': {'1. open': '16.1212',
#   '2. high': '16.1576',
#   '3. low': '15.9273',
#   '4. close': '16.0121',
#   '5. adjusted close': '13.7431',
#   '6. volume': '12012165',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-28': {'1. open': '16.0909',
#   '2. high': '16.1939',
#   '3. low': '16.0000',
#   '4. close': '16.0000',
#   '5. adjusted close': '13.7328',
#   '6. volume': '28203780',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-23': {'1. open': '16.4182',
#   '2. high': '16.4182',
#   '3. low': '15.9454',
#   '4. close': '16.0606',
#   '5. adjusted close': '13.7848',
#   '6. volume': '19590450',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-22': {'1. open': '16.2121',
#   '2. high': '16.3394',
#   '3. low': '15.9394',
#   '4. close': '16.1212',
#   '5. adjusted close': '13.8368',
#   '6. volume': '28014855',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-21': {'1. open': '16.4242',
#   '2. high': '16.4848',
#   '3. low': '15.9394',
#   '4. close': '16.0182',
#   '5. adjusted close': '13.7484',
#   '6. volume': '32174175',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-18': {'1. open': '16.8909',
#   '2. high': '16.9515',
#   '3. low': '16.3212',
#   '4. close': '16.3212',
#   '5. adjusted close': '14.0084',
#   '6. volume': '56025750',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-17': {'1. open': '17.3939',
#   '2. high': '17.6182',
#   '3. low': '17.2485',
#   '4. close': '17.3273',
#   '5. adjusted close': '14.8720',
#   '6. volume': '20040075',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-16': {'1. open': '17.0000',
#   '2. high': '17.1333',
#   '3. low': '16.6061',
#   '4. close': '17.0364',
#   '5. adjusted close': '14.6223',
#   '6. volume': '29401680',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-15': {'1. open': '17.0970',
#   '2. high': '17.4606',
#   '3. low': '17.0970',
#   '4. close': '17.1515',
#   '5. adjusted close': '14.7211',
#   '6. volume': '33409200',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-14': {'1. open': '17.2848',
#   '2. high': '17.3212',
#   '3. low': '16.9151',
#   '4. close': '17.0424',
#   '5. adjusted close': '14.6274',
#   '6. volume': '19957575',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-11': {'1. open': '17.2788',
#   '2. high': '17.6061',
#   '3. low': '17.1939',
#   '4. close': '17.4545',
#   '5. adjusted close': '14.9811',
#   '6. volume': '22458810',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-10': {'1. open': '17.5030',
#   '2. high': '17.6303',
#   '3. low': '17.3394',
#   '4. close': '17.4545',
#   '5. adjusted close': '14.9811',
#   '6. volume': '23940180',
#   '7. dividend amount': '0.2090',
#   '8. split coefficient': '1.0000'},
#  '2015-12-09': {'1. open': '17.0000',
#   '2. high': '17.7152',
#   '3. low': '16.9818',
#   '4. close': '17.6667',
#   '5. adjusted close': '14.9839',
#   '6. volume': '47833500',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-08': {'1. open': '16.9454',
#   '2. high': '16.9454',
#   '3. low': '16.5515',
#   '4. close': '16.7576',
#   '5. adjusted close': '14.2128',
#   '6. volume': '32438010',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-07': {'1. open': '17.2788',
#   '2. high': '17.3939',
#   '3. low': '16.8788',
#   '4. close': '16.9515',
#   '5. adjusted close': '14.3773',
#   '6. volume': '26038485',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-04': {'1. open': '17.3151',
#   '2. high': '17.3879',
#   '3. low': '16.7879',
#   '4. close': '17.0788',
#   '5. adjusted close': '14.4853',
#   '6. volume': '29007165',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-03': {'1. open': '17.1515',
#   '2. high': '17.8303',
#   '3. low': '17.0303',
#   '4. close': '17.4667',
#   '5. adjusted close': '14.8143',
#   '6. volume': '53560980',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-02': {'1. open': '16.8909',
#   '2. high': '17.0000',
#   '3. low': '16.3394',
#   '4. close': '16.4242',
#   '5. adjusted close': '13.9301',
#   '6. volume': '34838100',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  '2015-12-01': {'1. open': '16.8788',
#   '2. high': '17.0242',
#   '3. low': '16.6182',
#   '4. close': '16.9636',
#   '5. adjusted close': '14.3876',
#   '6. volume': '21762015',
#   '7. dividend amount': '0.0150',
#   '8. split coefficient': '1.0000'},
#  '2015-11-30': {'1. open': '16.6061',
#   '2. high': '17.0000',
#   '3. low': '16.4303',
#   '4. close': '16.8424',
#   '5. adjusted close': '14.2720',
#   '6. volume': '45753510',
#   '7. dividend amount': '0.0000',
#   '8. split coefficient': '1.0000'},
#  ...}

# %%
stocks = pd.DataFrame(info['Time Series (Daily)']).T
stocks
# Out:
#             1. open  2. high   3. low 4. close 5. adjusted close 6. volume  \
# 2019-12-04  35.3900  36.5700  35.3000  36.4200           36.4200  25791900
# 2019-12-03  35.5900  35.7100  34.9100  35.2900           35.2900  15999200
# 2019-12-02  34.9200  35.5200  34.8400  35.2800           35.2800  16447900
# 2019-11-29  34.6700  34.8300  34.3000  34.8000           34.7850  16530900
# 2019-11-28  34.4500  34.7000  34.0200  34.6000           34.5851  15850200
# ...             ...      ...      ...      ...               ...       ...
# 2000-12-28   2.9109   3.1294   2.8644   3.0632            2.2333     77449
# 2000-12-27   2.8811   2.9274   2.8314   2.9274            2.1343     27008
# 2000-12-26   2.8167   2.8347   2.7900   2.8314            2.0643      7839
# 2000-12-22   2.9307   2.9307   2.8148   2.8322            2.0649     23336
# 2000-12-21   2.8155   2.9885   2.8152   2.9606            2.1584     74224
#
#            7. dividend amount 8. split coefficient
# 2019-12-04             0.0000               1.0000
# 2019-12-03             0.0000               1.0000
# 2019-12-02             0.0150               1.0000
# 2019-11-29             0.0000               1.0000
# 2019-11-28             0.0000               1.0000
# ...                       ...                  ...
# 2000-12-28             0.0000               1.0000
# 2000-12-27             0.0000               1.0000
# 2000-12-26             0.0000               1.0000
# 2000-12-22             0.0000               1.0000
# 2000-12-21             0.0000               1.0000
#
# [4663 rows x 8 columns]

# %%
stocks[stocks['7. dividend amount'].astype(float) > 0.0]
# Out:
#             1. open  2. high   3. low 4. close 5. adjusted close 6. volume  \
# 2019-12-02  34.9200  35.5200  34.8400  35.2800           35.2800  16447900
# 2019-11-01  36.6600  36.9100  35.9100  36.3500           36.3343  18958400
# 2019-10-01  35.2200  35.3100  34.2000  34.2200           34.1911  17096300
# 2019-09-02  33.9000  34.1900  33.5000  33.5000           33.4574   8366100
# 2019-08-16  34.8000  34.8600  34.1300  34.3500           34.2911  14343000
# ...             ...      ...      ...      ...               ...       ...
# 2010-08-11  17.2165  17.2347  16.8522  17.0617           12.6272   9790656
# 2010-08-02  18.0316  18.1636  17.9314  18.0816           13.2213  12713512
# 2010-07-01  15.0718  15.4771  14.8032  15.4771           11.3094  26653574
# 2010-06-01  15.5090  15.8414  15.2585  15.4816           11.3035  12725152
# 2010-05-03  17.0753  17.3531  17.0480  17.2119           12.5573   9470897
#
#            7. dividend amount 8. split coefficient
# 2019-12-02             0.0150               1.0000
# 2019-11-01             0.0150               1.0000
# 2019-10-01             0.0150               1.0000
# 2019-09-02             0.0150               1.0000
# 2019-08-16             0.2393               1.0000
# ...                       ...                  ...
# 2010-08-11             0.2095               1.0000
# 2010-08-02             0.0120               1.0000
# 2010-07-01             0.0120               1.0000
# 2010-06-01             0.0120               1.0000
# 2010-05-03             0.0120               1.0000
#
# [131 rows x 8 columns]

# %%
stocks[stocks['8. split coefficient'] != '1.0000']
# Out:
#             1. open  2. high   3. low 4. close 5. adjusted close  6. volume  \
# 2018-11-21  34.9900  35.2500  34.5500  34.6900           33.5659   15986300
# 2016-10-18  24.2000  24.6667  23.9400  24.5733           21.6626   21750300
# 2015-07-14  19.2364  19.3818  19.0546  19.2970           15.9568   12717045
# 2014-06-06  18.0386  18.4132  17.6915  17.9835           13.8384   32614280
# 2013-05-21  16.3386  16.4488  16.0230  16.4438           12.5002   17863085
# 2009-08-31  14.5254  14.6210  14.3433  14.5618           10.6164   11722390
# 2008-06-02  16.3551  16.5165  15.8790  15.9784           11.6492    8377873
# 2007-10-01  15.3690  15.9022  15.2664  15.6969           11.4440    7147947
# 2005-10-03   8.8419   9.1532   8.8419   9.0572            6.6032   12117477
# 2004-10-20   5.4143   5.4641   5.3482   5.4641            3.9837  116681450
#
#            7. dividend amount 8. split coefficient
# 2018-11-21             0.0000               1.5000
# 2016-10-18             0.0000               1.1000
# 2015-07-14             0.0000               1.1000
# 2014-06-06             0.0000               1.1000
# 2013-05-21             0.0000               1.1000
# 2009-08-31             0.0000               1.1000
# 2008-06-02             0.0000               1.2500
# 2007-10-01             0.0000               2.0000
# 2005-10-03             0.0000              10.0000
# 2004-10-20             0.0000               0.0010

# %%
stocks.loc['2008-06-02']
# Out:
# 1. open                 16.3551
# 2. high                 16.5165
# 3. low                  15.8790
# 4. close                15.9784
# 5. adjusted close       11.6492
# 6. volume               8377873
# 7. dividend amount       0.0000
# 8. split coefficient     1.2500
# Name: 2008-06-02, dtype: object

# %%
stocks.loc['2008-06-10':'2008-06-02']
# Out:
#             1. open  2. high   3. low 4. close 5. adjusted close 6. volume  \
# 2008-06-10  14.9849  14.9849  14.4923  14.6951           10.7136  15651741
# 2008-06-09  15.5437  15.6472  15.0304  15.2084           11.0878   7767651
# 2008-06-06  15.8914  15.9867  15.4195  15.5603           11.3444   8574758
# 2008-06-05  15.6886  15.9577  15.4941  15.9370           11.6190   4619667
# 2008-06-04  15.4402  15.7093  15.3574  15.4113           11.2358   9829265
# 2008-06-03  16.0405  16.0984  15.4858  15.5230           11.3172   7106697
# 2008-06-02  16.3551  16.5165  15.8790  15.9784           11.6492   8377873
#
#            7. dividend amount 8. split coefficient
# 2008-06-10             0.0000               1.0000
# 2008-06-09             0.0000               1.0000
# 2008-06-06             0.0000               1.0000
# 2008-06-05             0.0000               1.0000
# 2008-06-04             0.0000               1.0000
# 2008-06-03             0.0000               1.0000
# 2008-06-02             0.0000               1.2500

# %%
stocks.iloc[0]
# Out:
# 1. open                  35.3900
# 2. high                  36.5700
# 3. low                   35.3000
# 4. close                 36.4200
# 5. adjusted close        36.4200
# 6. volume               25791900
# 7. dividend amount        0.0000
# 8. split coefficient      1.0000
# Name: 2019-12-04, dtype: object

# %%
stocks.iloc[0:5]
# Out:
#             1. open  2. high   3. low 4. close 5. adjusted close 6. volume  \
# 2019-12-04  35.3900  36.5700  35.3000  36.4200           36.4200  25791900
# 2019-12-03  35.5900  35.7100  34.9100  35.2900           35.2900  15999200
# 2019-12-02  34.9200  35.5200  34.8400  35.2800           35.2800  16447900
# 2019-11-29  34.6700  34.8300  34.3000  34.8000           34.7850  16530900
# 2019-11-28  34.4500  34.7000  34.0200  34.6000           34.5851  15850200
#
#            7. dividend amount 8. split coefficient
# 2019-12-04             0.0000               1.0000
# 2019-12-03             0.0000               1.0000
# 2019-12-02             0.0150               1.0000
# 2019-11-29             0.0000               1.0000
# 2019-11-28             0.0000               1.0000

# %%
stocks['5. adjusted close'].astype(float).describe()
# Out:
# count    4663.000000
# mean       12.412707
# std         8.918485
# min         1.400300
# 25%         6.029850
# 50%        11.106000
# 75%        14.887000
# max        38.474700
# Name: 5. adjusted close, dtype: float64

# %%
stocks.iloc[0:250]['5. adjusted close'].astype(float).describe()
# Out:
# count    250.000000
# mean      34.865113
# std        1.465186
# min       31.131900
# 25%       33.737300
# 50%       34.807400
# 75%       36.134200
# max       38.474700
# Name: 5. adjusted close, dtype: float64

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------

# %% [markdown]
# # Acessando a API

# %%
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
import matplotlib.pyplot as plt

# %%
ts = TimeSeries(key='1VI1L6694V2Q3CFA', output_format='pandas')

# intraday, meta_intra = ts.get_intraday(symbol='ITUB4.SA', interval='5min', outputsize='compact')
daily, meta_daily = ts.get_daily('ITUB4.SA')

# %%
daily.head()
# Out:
#             1. open  2. high  3. low  4. close   5. volume
# date
# 2019-12-03    35.59    35.71   34.91     35.29  15999200.0
# 2019-12-02    34.92    35.52   34.84     35.28  16447900.0
# 2019-11-29    34.67    34.83   34.30     34.80  16530900.0
# 2019-11-28    34.45    34.70   34.02     34.60  15850200.0
# 2019-11-27    34.70    34.93   34.26     34.70  19366600.0

# %%
daily['4. close'].plot(figsize=(17,6));

# %%
ti = TechIndicators(key='1VI1L6694V2Q3CFA', output_format='pandas')
rsi, meta_rsi = ti.get_rsi('ITUB4.SA')

# %%
rsi.plot(figsize=(17,8))
#plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()

# %%
macd, meta_macd = ti.get_macd('ITUB4.SA')

# %%
type(macd)
# Out:
# pandas.core.frame.DataFrame

# %%
type(meta_macd)
# Out:
# dict

# %%
macd.head()
# Out:
#             MACD_Signal  MACD_Hist    MACD
# date
# 2001-02-06       0.2505    -0.0596  0.1909
# 2001-02-07       0.2348    -0.0628  0.1720
# 2001-02-08       0.2202    -0.0584  0.1618
# 2001-02-09       0.2058    -0.0577  0.1480
# 2001-02-12       0.1918    -0.0556  0.1362

# %%
macd['MACD_Signal']['2019-05-01':].plot(figsize=(17,6))
macd['MACD']['2019-05-01':].plot(figsize=(17,6))
